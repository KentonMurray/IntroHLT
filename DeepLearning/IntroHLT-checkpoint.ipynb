# %% [markdown]
# # Introduction to Human Language Technology (601.467/667)
# ## Kenton Murray

# %% [markdown]
# ![PyTorch](Pictures/IntroHLT/PyTorch.png)

# %% [markdown]
# First, let's load PyTorch. (At this point you should have conda, pytorch, and jupyter notebook installed). Then we will check the version and use a simple comman.

# %%
import torch

# %%
torch.__version__
# Out:
# '1.9.0'

# %%
fc1 = torch.nn.Linear(3,2)

# %%
print(fc1)
# Out:
# Linear(in_features=3, out_features=2, bias=True)

# %% [markdown]
# Hopefully, you should be able to see the version and to print out a Linear layer.
#
#
#
#
#
# Now, let's return to last week's logistic regression examples.

# %% [markdown]
# ![LogisticRegression](Pictures/IntroHLT/LogisticRegression.png)

# %%
x = torch.Tensor([0,1])

# %%
print(x)
# Out:
# tensor([0., 1.])

# %%
W = torch.nn.Linear(2,1)

# %%
print(W)
print(W.weight)
print(W.bias)
# Out:
# Linear(in_features=2, out_features=1, bias=True)
# Parameter containing:
# tensor([[-0.3554, -0.5974]], requires_grad=True)
# Parameter containing:
# tensor([-0.2394], requires_grad=True)

# %%
LinearTransform = W(x)

# %%
print("LinearTransform:", LinearTransform)
# Out:
# LinearTransform: tensor([-1.2021], grad_fn=<AddBackward0>)

# %%
output = torch.sigmoid(LinearTransform)

# %%
print("output:", output)
# Out:
# output: tensor([0.2311], grad_fn=<SigmoidBackward>)

# %% [markdown]
# So what does this number mean?
#
# What happens when we try it again?

# %%
W = torch.nn.Linear(2,1)
LinearTransform = W(x)
print("LinearTransform:", LinearTransform)
output = torch.sigmoid(LinearTransform)
print("output:", output)
# Out:
# LinearTransform: tensor([-0.6212], grad_fn=<AddBackward0>)
# output: tensor([0.3495], grad_fn=<SigmoidBackward>)

# %% [markdown]
# Why does the number change?

# %%
for i in range(1,10):
    W = torch.nn.Linear(2,1)
    print(W.weight)
    i = i+1
# Out:
# Parameter containing:
# tensor([[ 0.7055, -0.1307]], requires_grad=True)
# Parameter containing:
# tensor([[-0.3631, -0.0564]], requires_grad=True)
# Parameter containing:
# tensor([[0.5110, 0.0677]], requires_grad=True)
# Parameter containing:
# tensor([[0.5051, 0.1598]], requires_grad=True)
# Parameter containing:
# tensor([[-0.6636, -0.5504]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0710,  0.2904]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2769, -0.5019]], requires_grad=True)
# Parameter containing:
# tensor([[-0.5132, -0.3038]], requires_grad=True)
# Parameter containing:
# tensor([[-0.5941, -0.4805]], requires_grad=True)

# %% [markdown]
# ![one_does_not](Pictures/IntroHLT/one_does_not.jpg)

# %% [markdown]
# We need to learn the weights!
#
# But first, what is $x$?
#
# ## Binary Language ID
#
# "gatos", "cat", "hola", "gata", "hello", "at"
#
# Is a word Spanish or English?
#
# ### Input vector, $x$
#
# Here, we are going to *manually* choose two features for each word to use as our embedding. Feature selection was common before Deep Learning. Now it is more common to let the embeddings be learned automatically. For our toy example here we will use the ratio of "o"s and "a"s in a word to its length, and its length.
#
# ![WordEmbeddings](Pictures/IntroHLT/WordEmbeddings.png)

# %%
# Assign values to all words
# variable_name = ratio, len
gatos = [0.4, 5]
cat = [0.33, 3]
hola = [0.5, 4]
gata = [0.5, 4]
hello = [0.2, 5]
at = [0.5, 2]

# %%
#Choose one of our examples to be x
x = torch.Tensor(cat)

W = torch.nn.Linear(2,1)
LinearTransform = W(x)
print("LinearTransform:", LinearTransform)
output = torch.sigmoid(LinearTransform)
print("output:", output)
# Out:
# LinearTransform: tensor([0.8019], grad_fn=<AddBackward0>)
# output: tensor([0.6904], grad_fn=<SigmoidBackward>)

# %% [markdown]
# ## Training
#
# Our weight matrix $W$ is only randomly initialized. It hasn't been trained, nor learned its weights. How do we do this?
#
# ### Labeled Data!

# %% [markdown]
# ![LabeledData](Pictures/IntroHLT/LabeledData.png)

# %%
English = torch.Tensor([[0],[1],[0],[0],[1],[1]])
print(English)
# Out:
# tensor([[0.],
#         [1.],
#         [0.],
#         [0.],
#         [1.],
#         [1.]])

# %%
Xs = [gatos, cat, hola, gata, hello, at]
Xs = torch.Tensor(Xs)
print(Xs)
# Out:
# tensor([[0.4000, 5.0000],
#         [0.3300, 3.0000],
#         [0.5000, 4.0000],
#         [0.5000, 4.0000],
#         [0.2000, 5.0000],
#         [0.5000, 2.0000]])

# %%
for x, output in zip(Xs, English):
    print("x:", x)
    LinearTransform = W(x)
    print("LinearTransform:", LinearTransform)
    predicted_output = torch.sigmoid(LinearTransform)
    print("predicted_output:", predicted_output)
    print("output:", output, "\n\n")
# Out:
# x: tensor([0.4000, 5.0000])
# LinearTransform: tensor([1.6982], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.8453], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
#
#
# x: tensor([0.3300, 3.0000])
# LinearTransform: tensor([0.8019], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.6904], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
#
#
# x: tensor([0.5000, 4.0000])
# LinearTransform: tensor([1.2886], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.7839], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
#
#
# x: tensor([0.5000, 4.0000])
# LinearTransform: tensor([1.2886], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.7839], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
#
#
# x: tensor([0.2000, 5.0000])
# LinearTransform: tensor([1.6410], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.8377], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
#
#
# x: tensor([0.5000, 2.0000])
# LinearTransform: tensor([0.4123], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.6017], grad_fn=<SigmoidBackward>)
# output: tensor([1.])

# %% [markdown]
# ![sad](Pictures/IntroHLT/sad.jpg)

# %% [markdown]
# ### But how garbage are they?!?!
#
# We need a *badness* metric. In Machine Learning, we call this a loss. We simply compare the correct answers to ours.

# %% [markdown]
# (predicted_output - output)

# %%
for x, output in zip(Xs, English):
    print("x:", x)
    LinearTransform = W(x)
    print("LinearTransform:", LinearTransform)
    predicted_output = torch.sigmoid(LinearTransform)
    print("predicted_output:", predicted_output)
    print("output:", output)
    loss = (predicted_output - output)
    print("loss:", loss, "\n\n")
# Out:
# x: tensor([0.4000, 5.0000])
# LinearTransform: tensor([1.6982], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.8453], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.8453], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# LinearTransform: tensor([0.8019], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.6904], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.3096], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# LinearTransform: tensor([1.2886], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.7839], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.7839], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# LinearTransform: tensor([1.2886], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.7839], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.7839], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# LinearTransform: tensor([1.6410], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.8377], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.1623], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# LinearTransform: tensor([0.4123], grad_fn=<AddBackward0>)
# predicted_output: tensor([0.6017], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.3983], grad_fn=<SubBackward0>)

# %% [markdown]
# However, we need to update the parameters. PyTorch has built in optimizers (more on this later). First, let's do some brief software engineering and define a class calle LogisticRegression.

# %%
class LogisticRegression(torch.nn.Module):
    def __init__(self, D_in):
        super(LogisticRegression, self).__init__()
        self.W = torch.nn.Linear(D_in, 1)
    
    def forward(self, x):
        LinearTransform = self.W(x)
        predicted_output = torch.sigmoid(LinearTransform)
        return predicted_output

# %% [markdown]
# Now we can make Logistic Regression Models for binary classification for $x$'s of different dimensions. Let's go back to our two feature example.

# %%
model = LogisticRegression(2)

# %% [markdown]
# And now we can use an optimizer on our model (again more details later).

# %%
optimizer = torch.optim.SGD(list(model.parameters()), lr=0.1)

# %% [markdown]
# Let's actually use this loss through backpropagation (more info also coming ....)

# %%
for x, output in zip(Xs, English):
    print("x:", x)
    predicted_output = model(x)
    print("predicted_output:", predicted_output)
    print("output:", output)
    loss = (predicted_output - output)
    print("loss:", loss, "\n\n")
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    #print("optimizer:", optimizer, "\n\n")
# Out:
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0252], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0252], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0791], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9209], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0403], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0403], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0378], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0378], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0177], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9823], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.1252], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.8748], grad_fn=<SubBackward0>)

# %% [markdown]
# ![sad](Pictures/IntroHLT/sad.jpg)
#
# Why are they still bad?
#
# Let's try going through the data more times.

# %%
for t in range (1, 50):
    for x, output in zip(Xs, English):
        print("x:", x)
        predicted_output = model(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = (predicted_output - output)
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0468], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0468], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.1106], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.8894], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0634], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0634], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0576], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0576], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0268], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9732], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.1545], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.8455], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0231], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0231], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0754], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9246], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0390], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0390], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0367], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0367], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0158], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9842], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.1269], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.8731], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0143], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0143], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0574], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9426], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0275], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0275], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0263], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0263], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0107], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9893], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.1090], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.8910], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0099], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0099], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0463], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9537], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0209], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0209], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0202], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0202], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0078], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9922], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0962], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9038], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0074], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0074], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0388], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9612], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0167], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0167], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0162], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0162], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0060], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9940], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0865], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9135], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0057], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0057], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0334], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9666], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0137], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0137], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0134], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0134], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0048], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9952], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0788], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9212], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0046], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0046], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0293], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9707], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0116], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0116], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0114], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0114], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0039], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9961], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0726], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9274], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0038], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0038], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0261], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9739], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0100], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0100], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0098], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0098], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0033], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9967], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0674], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9326], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0032], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0032], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0235], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9765], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0087], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0087], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0086], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0086], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0028], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9972], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0630], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9370], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0028], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0028], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0214], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9786], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0077], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0077], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0076], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0076], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0024], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9976], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0592], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9408], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0024], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0024], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0196], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9804], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0069], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0069], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0068], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0068], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0021], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9979], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0559], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9441], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0021], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0021], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0181], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9819], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0062], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0062], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0062], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0062], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0019], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9981], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0530], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9470], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0019], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0019], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0168], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9832], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0056], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0056], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0056], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0056], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0017], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9983], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0505], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9495], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0017], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0017], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0156], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9844], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0052], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0052], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0051], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0051], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0015], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9985], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0482], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9518], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0015], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0015], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0147], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9853], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0047], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0047], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0047], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0047], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0014], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9986], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0461], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9539], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0013], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0013], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0138], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9862], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0044], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0044], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0043], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0043], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9988], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0442], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9558], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0012], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0130], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9870], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0041], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0041], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0040], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0040], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9989], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0425], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9575], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0011], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0123], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9877], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0038], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0038], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0037], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0037], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9990], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0409], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9591], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0010], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0117], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9883], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0035], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0035], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0035], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0035], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9990], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0395], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9605], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0010], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0111], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9889], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0033], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0033], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0033], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0033], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0009], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9991], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0381], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9619], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0009], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0009], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0106], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9894], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0031], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0031], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0031], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0031], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0008], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9992], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0369], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9631], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0008], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0008], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0101], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9899], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0029], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0029], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0029], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0029], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0008], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9992], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0357], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9643], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0008], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0008], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0096], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9904], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0028], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0028], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0027], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0027], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0007], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9993], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0347], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9653], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0007], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0007], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0092], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9908], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0026], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0026], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0026], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0026], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0007], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9993], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0337], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9663], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0007], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0007], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0089], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9911], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0025], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0025], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0025], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0025], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0006], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9994], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0327], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9673], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0006], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0006], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0085], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9915], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0023], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0023], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0023], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0023], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0006], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9994], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0318], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9682], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0006], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0006], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0082], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9918], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0022], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0022], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0022], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0022], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0006], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9994], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0310], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9690], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0006], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0006], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0079], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9921], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0021], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0021], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0021], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0021], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0005], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9995], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0302], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9698], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0005], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0005], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0076], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9924], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0020], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0020], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0020], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0020], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0005], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9995], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0295], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9705], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0005], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0005], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0074], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9926], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0019], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0019], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0019], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0019], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0005], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9995], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0288], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9712], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0005], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0005], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0071], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9929], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0019], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0019], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0019], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0019], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9996], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0281], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9719], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0004], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0069], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9931], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0018], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0018], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0018], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0018], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9996], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0275], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9725], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0004], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0067], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9933], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0017], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0017], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0017], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0017], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9996], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0269], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9731], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0004], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0065], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9935], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0016], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0016], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0016], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0016], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9996], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0263], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9737], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0004], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0063], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9937], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0016], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0016], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0016], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0016], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9996], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0257], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9743], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0004], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0061], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9939], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0015], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0015], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0015], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0015], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0252], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9748], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0004], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0004], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0059], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9941], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0015], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0015], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0015], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0015], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0247], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9753], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0058], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9942], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0014], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0014], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0014], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0014], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0242], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9758], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0056], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9944], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0014], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0014], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0014], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0014], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0238], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9762], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0055], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9945], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0013], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0013], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0013], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0013], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0233], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9767], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0053], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9947], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0013], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0013], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0013], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0013], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0229], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9771], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0052], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9948], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0012], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0012], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0225], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9775], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0051], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9949], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0012], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0012], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9997], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0221], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9779], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0049], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9951], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0012], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0012], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0012], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9998], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0217], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9783], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0003], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0048], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9952], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0011], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0011], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9998], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0214], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9786], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0002], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0047], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9953], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0011], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0011], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9998], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0210], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9790], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0002], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0046], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9954], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0011], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0011], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9998], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0207], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9793], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0002], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0045], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9955], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0010], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0010], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9998], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0204], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9796], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0002], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0044], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9956], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0010], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0010], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor([0.0010], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0002], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9998], grad_fn=<SubBackward0>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0200], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor([-0.9800], grad_fn=<SubBackward0>)

# %% [markdown]
# What is a loss? What happens with it? What is this backprop?
#
#
# ![forward](Pictures/IntroHLT/forward.jpg)

# %% [markdown]
# ![forward2](Pictures/IntroHLT/forward2.png)
#
# For our Linear Regression example, this is simply the $\sigma(W(x))$
#
# Now remember that our loss calculates a score between the predicted output and the correct output. We want these to be as close as possible - so we want to minimize this.

# %% [markdown]
# ![GradientDescent](Pictures/IntroHLT/GradientDescent.png)

# %% [markdown]
# ![chan](Pictures/IntroHLT/chan.jpg)
#
# It is simply the method of calculating the gradients for all the variables. The method goes through all the variables in the network in reverse order calculating the gradients using the chain rule from calculus.

# %% [markdown]
# ![backprop](Pictures/IntroHLT/backprop.png)
#
# ### Chain Rule
#
# $\frac{\delta}{\delta \theta}f(g(\theta))$ = $f'(g(\theta))g'(\theta)$
#
# $f(g(\theta)) = \sigma(W(\theta))$
#
# $ = \sigma(W(\theta))(1-\sigma(W(\theta)))(W'(\theta)) $

# %% [markdown]
# ### Better Loss Functions
#
# The loss function we have defined so far is a simple difference between the predicted and the correct value. However, this is prone to issues such as the sign of the difference. There are other more commonly used loss functions designed to mitigate some of these problems.
#
# * Mean Absolute Error Loss (L1)
# * Mean Squared Error (MSE)
# * Cross-Entropy

# %% [markdown]
# MSE: $\frac{1}{n}\sum_{1}^{n}{(Correct - Predicted)^2}$

# %%
criterion = torch.nn.MSELoss(reduction='sum')

# %%
for t in range (1, 50):
    for x, output in zip(Xs, English):
        print("x:", x)
        predicted_output = model(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = criterion(predicted_output, output)
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0153], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0002, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0610], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.8818, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0356], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0013, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0355], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0013, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0176], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.9650, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.1310], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.7551, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0243], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0006, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0803], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.8458, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0534], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0029, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0529], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0028, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0288], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.9433, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.1623], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.7018, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0430], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0018, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.1121], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.7884, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0876], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0077, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0857], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0073, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0518], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.8992, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.2106], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.6232, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0872], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0076, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.1663], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.6950, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.1576], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0248, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.1482], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0220, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0992], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.8115, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.2833], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5136, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.1925], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0371, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.2475], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5663, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.2764], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0764, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.2400], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0576, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.1697], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.6894, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.3624], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.4066, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.3502], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1227, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3187], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.4641, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3808], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1450, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3109], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.0967, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2224], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.6047, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4091], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3492, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4503], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2027, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3555], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.4154, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4310], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1858, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3447], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1188, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2468], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5674, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4293], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3257, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4897], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2398, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3718], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3946, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4516], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2040, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3589], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1288, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2566], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5527, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4387], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3151, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5042], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2542, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3792], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3853, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4600], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2116, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3648], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1331, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2601], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5474, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4438], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3094, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5091], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2592, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3830], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3807, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4633], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2147, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3672], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1348, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2611], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5459, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4471], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3057, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5101], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2602, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3852], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3780, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4647], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2159, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3681], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1355, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2610], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5461, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4498], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3027, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5097], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2598, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3868], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3760, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4652], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2164, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3685], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1358, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2605], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5468, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4522], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3001, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5086], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2586, grad_fn=<MseLossBackward>)
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3881], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3744, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4654], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2166, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3686], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1359, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2598], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5479, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4544], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2977, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5072], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2572, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3894], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3729, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4655], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2167, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3687], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1359, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2591], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5490, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4566], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2953, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5057], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2558, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3906], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3714, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4655], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2166, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3687], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1359, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2583], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5501, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4588], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2929, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5042], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2542, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3917], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3700, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4654], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2166, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3686], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1359, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2575], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5513, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4609], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2906, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5027], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2527, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3929], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3686, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4654], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2166, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3686], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1359, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2567], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5525, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4630], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2883, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5011], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2512, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3940], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3672, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4653], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2165, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3686], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1358, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2559], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5537, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4652], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2860, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4996], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2496, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3952], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3658, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4653], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2165, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3685], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1358, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2551], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5548, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4673], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2838, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4981], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2481, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3963], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3644, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4652], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2164, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3685], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1358, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2544], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5560, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4694], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2815, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4965], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2465, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3975], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3630, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4652], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2164, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3685], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1358, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2536], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5571, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4715], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2793, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4950], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2450, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3986], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3617, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4651], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2163, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3684], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1357, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2528], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5583, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4736], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2771, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4935], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2435, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3998], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3603, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4650], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2162, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3684], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1357, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2521], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5594, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4757], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2749, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4919], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2420, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4009], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3589, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4650], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2162, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3683], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1357, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2513], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5605, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4778], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2727, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4904], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2405, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4020], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3576, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4649], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2161, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3683], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1356, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2506], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5617, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4798], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2706, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4889], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2390, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4031], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3562, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4648], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2160, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3682], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1356, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2498], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5628, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4819], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2685, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4873], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2375, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4043], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3549, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4647], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2160, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3682], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1355, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2491], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5639, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4839], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2663, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4858], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2360, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4054], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3536, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4647], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2159, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3681], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1355, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2483], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5650, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4860], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2642, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4843], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2345, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4065], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3522, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4646], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2158, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3680], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1355, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2476], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5661, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4880], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4828], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2331, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4076], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3509, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4645], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2158, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3680], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1354, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2469], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5672, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4900], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2601, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4812], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2316, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4087], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3496, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4644], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2157, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3679], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1354, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2462], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5683, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4920], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2581, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4797], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2301, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4098], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3483, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4643], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2156, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3679], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1353, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2455], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5693, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4940], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2560, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4782], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2287, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4109], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3470, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4642], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2155, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3678], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1353, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2447], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5704, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4960], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2540, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4767], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2273, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4120], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3457, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4642], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2154, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3677], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1352, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2440], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5715, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4980], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2520, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4752], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2258, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4131], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3444, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4641], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2154, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3677], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1352, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2434], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5725, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.4999], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2501, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4737], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2244, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4142], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3431, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4640], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2153, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3676], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1351, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2427], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5736, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5019], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2481, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4722], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2230, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4153], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3419, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4639], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2152, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3675], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1351, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2420], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5746, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5038], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2462, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4707], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2216, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4164], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3406, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4638], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2151, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3675], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1350, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2413], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5756, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5058], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2443, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4692], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2202, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4175], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3393, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4637], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2150, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3674], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1350, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2406], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5766, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5077], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2424, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4677], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2188, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4185], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3381, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4636], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2149, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3673], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1349, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2400], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5777, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5096], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2405, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4663], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2174, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4196], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3368, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4635], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2148, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3673], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1349, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2393], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5787, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5115], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2386, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4648], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2160, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4207], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3356, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4634], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2147, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3672], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1348, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2386], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5797, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5134], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2368, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4633], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2147, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4218], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3344, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4633], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2146, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3671], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1348, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2380], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5807, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5153], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2350, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4619], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2133, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4228], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3331, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4632], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2145, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3671], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1347, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2373], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5816, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5171], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2332, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4604], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2120, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4239], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3319, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4631], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2144, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3670], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1347, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2367], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5826, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5190], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2314, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4590], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2106, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4249], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3307, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4630], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2143, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3669], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1346, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2361], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5836, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5208], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2296, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4575], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2093, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4260], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3295, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4629], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2142, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3668], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1346, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2354], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5845, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5227], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2278, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4561], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2080, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4270], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3283, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4627], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2141, grad_fn=<MseLossBackward>)
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3668], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1345, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2348], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5855, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5245], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2261, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4546], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2067, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4281], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.3271, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4626], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.2140, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3667], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# loss: tensor(0.1344, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2342], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.5864, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.5263], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# loss: tensor(0.2244, grad_fn=<MseLossBackward>)

# %% [markdown]
# What are some of the other things we can try?
#
# *  More loss functions
# *  Different optimizers
# *  More times through the data
# *  Minibatches
# *  More Data
# *  Different Initializations
#
# ## Neural Network

# %%
class TwoLayerNet(torch.nn.Module):
    def __init__(self, D_in, H, D_out):
        super(TwoLayerNet, self).__init__()
        self.linear1 = torch.nn.Linear(D_in, H)
        self.linear2 = torch.nn.Linear(H, D_out)

    def forward(self, x):
        h_relu = self.linear1(x).clamp(min=0)
        y_pred = self.linear2(h_relu)
        return y_pred
    

# D_in is input dimension; H is hidden dimension; D_out is output dimension.
D_in, H, D_out = 2, 2, 1

# Construct model
model2 = TwoLayerNet(D_in, H, D_out)

# Loss, Optimizer, and Proximal Gradient
criterion = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.SGD(list(model2.parameters()), lr=0.1)
print(list(model2.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.0861, -0.3097],
#         [-0.4803,  0.3839]], requires_grad=True), Parameter containing:
# tensor([ 0.6667, -0.3263], requires_grad=True), Parameter containing:
# tensor([[ 0.3753, -0.5971]], requires_grad=True), Parameter containing:
# tensor([-0.2337], requires_grad=True)]

# %%
for t in range (1, 50):
    for x, output in zip(Xs, English):
        print("x:", x)
        predicted_output = model2(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = criterion(predicted_output, output)
        print(list(model2.parameters()))
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5181], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1693, -0.5731],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7416, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5684, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5181], requires_grad=True)]
# loss: tensor(0.2684, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4589], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1693, -0.5731],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7416, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5684, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4145], requires_grad=True)]
# loss: tensor(0.2927, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.7210], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1895, -0.3885],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8031, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5769, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5227], requires_grad=True)]
# loss: tensor(0.5198, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3785], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1480, -0.7213],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7199, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5273, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3785], requires_grad=True)]
# loss: tensor(0.1432, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3028], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1480, -0.7213],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7199, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5273, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3028], requires_grad=True)]
# loss: tensor(0.4861, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.6275], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1480, -0.7213],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7199, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5273, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4422], requires_grad=True)]
# loss: tensor(0.1388, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5167], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1676, -0.6427],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7592, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5535, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5167], requires_grad=True)]
# loss: tensor(0.2670, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4134], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1676, -0.6427],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7592, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5535, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4134], requires_grad=True)]
# loss: tensor(0.3441, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5307], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1676, -0.6427],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7592, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5535, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5307], requires_grad=True)]
# loss: tensor(0.2816, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4246], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1676, -0.6427],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7592, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5535, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4246], requires_grad=True)]
# loss: tensor(0.1803, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3397], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1676, -0.6427],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7592, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5535, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3397], requires_grad=True)]
# loss: tensor(0.4361, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.7803], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1676, -0.6427],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7592, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5535, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4717], requires_grad=True)]
# loss: tensor(0.0482, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5157], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1798, -0.5941],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7835, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5780, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5157], requires_grad=True)]
# loss: tensor(0.2659, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4476], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1798, -0.5941],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7835, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5780, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4125], requires_grad=True)]
# loss: tensor(0.3052, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.7206], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2008, -0.4025],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8474, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5847, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5230], requires_grad=True)]
# loss: tensor(0.5192, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3789], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1587, -0.7395],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7631, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5360, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3789], requires_grad=True)]
# loss: tensor(0.1436, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3031], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1587, -0.7395],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7631, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5360, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3031], requires_grad=True)]
# loss: tensor(0.4856, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.6373], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1587, -0.7395],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7631, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5360, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4425], requires_grad=True)]
# loss: tensor(0.1316, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5150], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output:
# C:\Users\Public\Anaconda3\envs\introHLT\lib\site-packages\ipykernel_launcher.py:6: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
# tensor([0.])
# [Parameter containing:
# tensor([[ 0.1781, -0.6618],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8020, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5624, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5150], requires_grad=True)]
# loss: tensor(0.2653, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4120], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1781, -0.6618],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8020, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5624, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4120], requires_grad=True)]
# loss: tensor(0.3457, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5296], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1781, -0.6618],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8020, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5624, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5296], requires_grad=True)]
# loss: tensor(0.2805, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4237], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1781, -0.6618],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8020, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5624, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4237], requires_grad=True)]
# loss: tensor(0.1795, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3390], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1781, -0.6618],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8020, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5624, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3390], requires_grad=True)]
# loss: tensor(0.4370, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.7903], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1781, -0.6618],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8020, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5624, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4712], requires_grad=True)]
# loss: tensor(0.0440, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5131], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1899, -0.6146],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8256, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5862, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5131], requires_grad=True)]
# loss: tensor(0.2633, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4365], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1899, -0.6146],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8256, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5862, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4105], requires_grad=True)]
# loss: tensor(0.3175, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.7193], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2117, -0.4164],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8916, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5912, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5232], requires_grad=True)]
# loss: tensor(0.5174, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3793], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1692, -0.7566],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8066, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5434, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3793], requires_grad=True)]
# loss: tensor(0.1439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3034], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1692, -0.7566],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8066, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5434, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3034], requires_grad=True)]
# loss: tensor(0.4852, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.6481], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1692, -0.7566],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8066, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5434, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4428], requires_grad=True)]
# loss: tensor(0.1238, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5131], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1883, -0.6801],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8448, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5700, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5131], requires_grad=True)]
# loss: tensor(0.2633, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4105], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1883, -0.6801],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8448, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5700, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4105], requires_grad=True)]
# loss: tensor(0.3475, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5284], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1883, -0.6801],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8448, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5700, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5284], requires_grad=True)]
# loss: tensor(0.2792, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4227], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1883, -0.6801],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8448, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5700, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4227], requires_grad=True)]
# loss: tensor(0.1787, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3382], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1883, -0.6801],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8448, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5700, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3382], requires_grad=True)]
# loss: tensor(0.4380, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.8004], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1883, -0.6801],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8448, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5700, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4705], requires_grad=True)]
# loss: tensor(0.0398, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5105], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1997, -0.6346],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8676, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5931, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5105], requires_grad=True)]
# loss: tensor(0.2606, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4259], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1997, -0.6346],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8676, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5931, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4084], requires_grad=True)]
# loss: tensor(0.3296, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.7173], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2222, -0.4303],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9357, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5965, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5232], requires_grad=True)]
# loss: tensor(0.5146, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3797], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1794, -0.7727],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8501, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5498, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3797], requires_grad=True)]
# loss: tensor(0.1442, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3038], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1794, -0.7727],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8501, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5498, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3038], requires_grad=True)]
# loss: tensor(0.4847, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.6599], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1794, -0.7727],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8501, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5498, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4430], requires_grad=True)]
# loss: tensor(0.1157, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5110], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1981, -0.6979],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8875, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5767, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5110], requires_grad=True)]
# loss: tensor(0.2612, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4088], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1981, -0.6979],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8875, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5767, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4088], requires_grad=True)]
# loss: tensor(0.3495, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5271], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1981, -0.6979],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8875, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5767, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5271], requires_grad=True)]
# loss: tensor(0.2778, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4217], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1981, -0.6979],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8875, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5767, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4217], requires_grad=True)]
# loss: tensor(0.1778, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3373], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1981, -0.6979],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8875, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5767, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3373], requires_grad=True)]
# loss: tensor(0.4391, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.8106], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1981, -0.6979],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8875, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5767, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4699], requires_grad=True)]
# loss: tensor(0.0359, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5077], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2090, -0.6542],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9093, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5991, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5077], requires_grad=True)]
# loss: tensor(0.2578, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4157], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2090, -0.6542],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9093, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5991, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4062], requires_grad=True)]
# loss: tensor(0.3414, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.7147], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2321, -0.4441],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9793, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6009, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5231], requires_grad=True)]
# loss: tensor(0.5107, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3801], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1892, -0.7877],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8935, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5553, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3801], requires_grad=True)]
# loss: tensor(0.1445, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3041], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1892, -0.7877],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8935, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5553, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3041], requires_grad=True)]
# loss: tensor(0.4843, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.6724], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1892, -0.7877],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8935, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5553, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4433], requires_grad=True)]
# loss: tensor(0.1073, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5088], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2074, -0.7149],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9298, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5824, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5088], requires_grad=True)]
# loss: tensor(0.2589, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4070], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2074, -0.7149],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9298, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5824, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4070], requires_grad=True)]
# loss: tensor(0.3516, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5256], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2074, -0.7149],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9298, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5824, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5256], requires_grad=True)]
# loss: tensor(0.2763, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4205], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2074, -0.7149],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9298, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5824, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4205], requires_grad=True)]
# loss: tensor(0.1768, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3364], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2074, -0.7149],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9298, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5824, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3364], requires_grad=True)]
# loss: tensor(0.4404, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.8207], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2074, -0.7149],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9298, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5824, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4691], requires_grad=True)]
# loss: tensor(0.0322, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5050], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2178, -0.6732],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9507, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6040, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5050], requires_grad=True)]
# loss: tensor(0.2550, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4059], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2178, -0.6732],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9507, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6040, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4040], requires_grad=True)]
# loss: tensor(0.3530, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.7113], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2415, -0.4578],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0225, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6044, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5228], requires_grad=True)]
# loss: tensor(0.5060, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3806], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1985, -0.8018],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9365, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5600, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3806], requires_grad=True)]
# loss: tensor(0.1448, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3044], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1985, -0.8018],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9365, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5600, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3044], requires_grad=True)]
# loss: tensor(0.4838, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.6856], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1985, -0.8018],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9365, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5600, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4436], requires_grad=True)]
# loss: tensor(0.0988, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5064], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2161, -0.7313],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9717, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5872, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5064], requires_grad=True)]
# loss: tensor(0.2565, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4051], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2161, -0.7313],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9717, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5872, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4051], requires_grad=True)]
# loss: tensor(0.3539, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5241], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2161, -0.7313],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9717, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5872, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5241], requires_grad=True)]
# loss: tensor(0.2747, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4193], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2161, -0.7313],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9717, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5872, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4193], requires_grad=True)]
# loss: tensor(0.1758, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3354], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2161, -0.7313],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9717, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5872, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3354], requires_grad=True)]
# loss: tensor(0.4416, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.8307], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2161, -0.7313],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9717, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5872, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4683], requires_grad=True)]
# loss: tensor(0.0287, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.5022], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2260, -0.6916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9916, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6081, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5022], requires_grad=True)]
# loss: tensor(0.2522, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4018], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2260, -0.6916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9916, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6081, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4018], requires_grad=True)]
# loss: tensor(0.3579, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5214], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2260, -0.6916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9916, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6081, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5214], requires_grad=True)]
# loss: tensor(0.2719, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4171], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2260, -0.6916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9916, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6081, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4171], requires_grad=True)]
# loss: tensor(0.1740, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3337], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2260, -0.6916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9916, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6081, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3337], requires_grad=True)]
# loss: tensor(0.4440, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9057], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2260, -0.6916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9916, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6081, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4670], requires_grad=True)]
# loss: tensor(0.0089, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4858], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2318, -0.6686],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0031, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6217, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4858], requires_grad=True)]
# loss: tensor(0.2360, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.4345], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2318, -0.6686],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0031, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6217, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3887], requires_grad=True)]
# loss: tensor(0.3198, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.7350], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2550, -0.4577],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0734, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6300, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5018], requires_grad=True)]
# loss: tensor(0.5402, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3548], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2087, -0.8281],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9808, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5756, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3548], requires_grad=True)]
# loss: tensor(0.1259, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.2838], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2087, -0.8281],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9808, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5756, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2838], requires_grad=True)]
# loss: tensor(0.5129, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.6739], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2087, -0.8281],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9808, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.5756, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4271], requires_grad=True)]
# loss: tensor(0.1063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4923], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2274, -0.7531],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0183, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6036, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4923], requires_grad=True)]
# loss: tensor(0.2423, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3938], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2274, -0.7531],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0183, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6036, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3938], requires_grad=True)]
# loss: tensor(0.3675, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5151], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2274, -0.7531],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0183, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6036, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5151], requires_grad=True)]
# loss: tensor(0.2653, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4120], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2274, -0.7531],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0183, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6036, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4120], requires_grad=True)]
# loss: tensor(0.1698, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3296], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2274, -0.7531],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0183, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6036, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3296], requires_grad=True)]
# loss: tensor(0.4494, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.8415], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2274, -0.7531],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0183, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6036, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4637], requires_grad=True)]
# loss: tensor(0.0251, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4954], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2370, -0.7148],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0375, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6234, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4954], requires_grad=True)]
# loss: tensor(0.2454, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3963], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2370, -0.7148],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0375, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6234, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3963], requires_grad=True)]
# loss: tensor(0.3644, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.5171], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2370, -0.7148],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0375, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6234, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5171], requires_grad=True)]
# loss: tensor(0.2673, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4136], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2370, -0.7148],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0375, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6234, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4136], requires_grad=True)]
# loss: tensor(0.1711, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3309], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2370, -0.7148],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0375, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6234, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3309], requires_grad=True)]
# loss: tensor(0.4477, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9176], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2370, -0.7148],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0375, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6234, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4647], requires_grad=True)]
# loss: tensor(0.0068, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4812], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2422, -0.6942],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0477, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6354, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4812], requires_grad=True)]
# ...
# tensor([ 2.2815, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6639, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3912], requires_grad=True)]
# loss: tensor(0.1531, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3130], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2912, -0.8012],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2815, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6639, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3130], requires_grad=True)]
# loss: tensor(0.4720, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9980], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2912, -0.8012],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2815, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6639, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4504], requires_grad=True)]
# loss: tensor(3.9801e-06, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4508], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2913, -0.8006],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2818, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6643, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4508], requires_grad=True)]
# loss: tensor(0.2032, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3606], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2913, -0.8006],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2818, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6643, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3606], requires_grad=True)]
# loss: tensor(0.4088, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4885], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2913, -0.8006],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2818, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6643, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4885], requires_grad=True)]
# loss: tensor(0.2386, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3908], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2913, -0.8006],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2818, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6643, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3908], requires_grad=True)]
# loss: tensor(0.1527, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3126], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2913, -0.8006],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2818, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6643, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3126], requires_grad=True)]
# loss: tensor(0.4725, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9989], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2913, -0.8006],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2818, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6643, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4501], requires_grad=True)]
# loss: tensor(1.1615e-06, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4503], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8004],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2819, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4503], requires_grad=True)]
# loss: tensor(0.2028, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3603], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8004],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2819, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3603], requires_grad=True)]
# loss: tensor(0.4093, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4882], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8004],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2819, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4882], requires_grad=True)]
# loss: tensor(0.2384, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3906], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8004],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2819, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3906], requires_grad=True)]
# loss: tensor(0.1525, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3125], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8004],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2819, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3125], requires_grad=True)]
# loss: tensor(0.4727, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9994], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8004],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2819, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4500], requires_grad=True)]
# loss: tensor(3.3898e-07, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4501], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8002],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2820, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4501], requires_grad=True)]
# loss: tensor(0.2026, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3601], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8002],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2820, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3601], requires_grad=True)]
# loss: tensor(0.4095, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4881], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8002],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2820, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4881], requires_grad=True)]
# loss: tensor(0.2382, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3904], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8002],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2820, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3904], requires_grad=True)]
# loss: tensor(0.1524, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3124], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8002],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2820, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3124], requires_grad=True)]
# loss: tensor(0.4729, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9997], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8002],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2820, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6645, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4499], requires_grad=True)]
# loss: tensor(9.8969e-08, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4499], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4499], requires_grad=True)]
# loss: tensor(0.2025, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3600], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3600], requires_grad=True)]
# loss: tensor(0.4097, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4880], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4880], requires_grad=True)]
# loss: tensor(0.2381, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3904], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3904], requires_grad=True)]
# loss: tensor(0.1524, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3123], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3123], requires_grad=True)]
# loss: tensor(0.4729, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9998], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4498], requires_grad=True)]
# loss: tensor(2.8979e-08, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.4499], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4499], requires_grad=True)]
# loss: tensor(0.2024, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.3599], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3599], requires_grad=True)]
# loss: tensor(0.4097, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.4879], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4879], requires_grad=True)]
# loss: tensor(0.2381, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.3903], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3903], requires_grad=True)]
# loss: tensor(0.1524, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.3123], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3123], requires_grad=True)]
# loss: tensor(0.4730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.9999], grad_fn=<AddBackward0>)
# predicted_output.grad: None
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8001],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4498], requires_grad=True)]
# loss: tensor(8.4475e-09, grad_fn=<MseLossBackward>)

# %% [markdown]
# ## Why Deeper?

# %%
class EightLayerNet(torch.nn.Module):
    def __init__(self, D_in, H, D_out):
        super(EightLayerNet, self).__init__()
        self.linear1 = torch.nn.Linear(D_in, H)
        self.linear2 = torch.nn.Linear(H, H)
        self.linear3 = torch.nn.Linear(H, H)
        self.linear4 = torch.nn.Linear(H, H)
        self.linear5 = torch.nn.Linear(H, H)
        self.linear6 = torch.nn.Linear(H, H)
        self.linear7 = torch.nn.Linear(H, H)
        self.linear8 = torch.nn.Linear(H, D_out)

    def forward(self, x):
        h_relu = self.linear1(x).clamp(min=0)
        h_relu2 = self.linear2(h_relu)
        h_relu3 = self.linear3(h_relu2)
        h_relu4 = self.linear4(h_relu3)
        h_relu5 = self.linear5(h_relu4)
        h_relu6 = self.linear6(h_relu5)
        h_relu7 = self.linear7(h_relu6)
        y_pred = self.linear8(h_relu7)
        return y_pred
    

# D_in is input dimension; H is hidden dimension; D_out is output dimension.
D_in, H, D_out = 2, 4, 1

# Construct model
model8 = EightLayerNet(D_in, H, D_out)

# Loss, Optimizer, and Proximal Gradient
criterion = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.SGD(list(model2.parameters()), lr=0.1)
print(list(model8.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.6424,  0.1296],
#         [-0.0156,  0.6513],
#         [ 0.0760,  0.2171],
#         [ 0.2923,  0.3507]], requires_grad=True), Parameter containing:
# tensor([ 0.3033, -0.3790,  0.2678, -0.0189], requires_grad=True), Parameter containing:
# tensor([[-0.2819, -0.0837, -0.1564,  0.2387],
#         [-0.2601, -0.2592,  0.2486,  0.2023],
#         [ 0.1555,  0.4985, -0.2878, -0.0495],
#         [-0.2454, -0.4824,  0.1429,  0.2333]], requires_grad=True), Parameter containing:
# tensor([ 0.0871,  0.0315, -0.2115, -0.2815], requires_grad=True), Parameter containing:
# tensor([[ 0.4783,  0.4812, -0.4707, -0.0440],
#         [-0.4070,  0.2737, -0.3041, -0.3743],
#         [ 0.0208, -0.0410,  0.4279, -0.3769],
#         [ 0.2437, -0.2150, -0.4834, -0.0580]], requires_grad=True), Parameter containing:
# tensor([0.2695, 0.4822, 0.2320, 0.1880], requires_grad=True), Parameter containing:
# tensor([[ 0.3235, -0.2275,  0.0768,  0.2460],
#         [ 0.3084, -0.3215,  0.4021,  0.4775],
#         [ 0.1532, -0.0979, -0.2408, -0.1124],
#         [ 0.1856,  0.0931, -0.1146, -0.3356]], requires_grad=True), Parameter containing:
# tensor([ 0.0185, -0.1760,  0.0498,  0.3905], requires_grad=True), Parameter containing:
# tensor([[ 0.3070,  0.1210,  0.0043,  0.1332],
#         [-0.4696, -0.3214, -0.2035, -0.2541],
#         [ 0.1082,  0.2711, -0.4117, -0.1735],
#         [-0.1572,  0.2082,  0.2471, -0.2494]], requires_grad=True), Parameter containing:
# tensor([ 0.1514, -0.4379, -0.4669,  0.2379], requires_grad=True), Parameter containing:
# tensor([[-0.0142,  0.3460, -0.2896, -0.1257],
#         [-0.1806, -0.4295, -0.2604, -0.4889],
#         [ 0.0423,  0.1468,  0.2723,  0.2276],
#         [ 0.2142, -0.1813, -0.1644, -0.3176]], requires_grad=True), Parameter containing:
# tensor([-0.4972, -0.0412, -0.3229,  0.3748], requires_grad=True), Parameter containing:
# tensor([[-0.4079,  0.0665, -0.4864,  0.2850],
#         [-0.0656, -0.2587,  0.4055,  0.0771],
#         [ 0.3576,  0.2151,  0.0607,  0.2162],
#         [-0.1092, -0.3981,  0.0434,  0.3287]], requires_grad=True), Parameter containing:
# tensor([ 0.4151, -0.2874, -0.4917,  0.1155], requires_grad=True), Parameter containing:
# tensor([[-0.3726, -0.3192, -0.4520, -0.4381]], requires_grad=True), Parameter containing:
# tensor([0.1731], requires_grad=True)]

# %%
for t in range (1, 50):
    for x, output in zip(Xs, English):
        print("x:", x)
        predicted_output = model8(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = criterion(predicted_output, output)
        #print(list(model8.parameters()))
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.4000, 5.0000])
# predicted_output: tensor([0.0797], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0063, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.3300, 3.0000])
# predicted_output: tensor([0.0715], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8622, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 4.0000])
# predicted_output: tensor([0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.2000, 5.0000])
# predicted_output: tensor([0.0813], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8439, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0.5000, 2.0000])
# predicted_output: tensor([0.0656], grad_fn=<AddBackward0>)
# output: tensor([1.])
# loss: tensor(0.8730, grad_fn=<MseLossBackward>)

# %% [markdown]
# ### And Operator
# *  0 x 0 = 0
# *  1 x 0 = 0
# *  0 x 1 = 0
# *  1 x 1 = 1
#
# ### Or Operator
# *  0 + 0 = 0
# *  1 + 0 = 1
# *  0 + 1 = 1
# *  1 + 1 = 1
#
# ### Xor Operator
# *  0 xor 0 = 0
# *  1 xor 0 = 1
# *  0 xor 1 = 1
# *  1 xor 1 = 0

# %%
bits = torch.Tensor([[0.,0.],[1.,0.],[0.,1.],[1.,1.]])
and_y = torch.Tensor([[0.],[0.],[0.],[1.]])
or_y = torch.Tensor([[0.],[1.],[1.],[1.]])
xor_y = torch.Tensor([[0.],[1.],[1.],[0.]])

# %% [markdown]
# ### Logistic Regression And

# %%
for t in range (1, 50):
    for x, output in zip(bits, and_y):
        print("x:", x)
        predicted_output = model(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = criterion(predicted_output, output)
        print(list(model.parameters()))
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0., 0.])
# predicted_output: tensor([0.5232], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0005, -0.3515]], requires_grad=True), Parameter containing:
# tensor([0.0929], requires_grad=True)]
# loss: tensor(0.2737, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.5168], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0005, -0.3515]], requires_grad=True), Parameter containing:
# tensor([0.0668], requires_grad=True)]
# loss: tensor(0.2671, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4230], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0253, -0.3515]], requires_grad=True), Parameter containing:
# tensor([0.0410], requires_grad=True)]
# loss: tensor(0.1789, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4068], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0253, -0.3722]], requires_grad=True), Parameter containing:
# tensor([0.0203], requires_grad=True)]
# loss: tensor(0.3519, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.5122], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0033, -0.3435]], requires_grad=True), Parameter containing:
# tensor([0.0489], requires_grad=True)]
# loss: tensor(0.2624, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.5067], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0033, -0.3435]], requires_grad=True), Parameter containing:
# tensor([0.0233], requires_grad=True)]
# loss: tensor(0.2567, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4145], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0220, -0.3435]], requires_grad=True), Parameter containing:
# tensor([-0.0020], requires_grad=True)]
# loss: tensor(0.1718, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3994], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0220, -0.3637]], requires_grad=True), Parameter containing:
# tensor([-0.0221], requires_grad=True)]
# loss: tensor(0.3607, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.5017], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0068, -0.3349]], requires_grad=True), Parameter containing:
# tensor([0.0067], requires_grad=True)]
# loss: tensor(0.2517, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4971], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0068, -0.3349]], requires_grad=True), Parameter containing:
# tensor([-0.0184], requires_grad=True)]
# loss: tensor(0.2471, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4066], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0181, -0.3349]], requires_grad=True), Parameter containing:
# tensor([-0.0432], requires_grad=True)]
# loss: tensor(0.1653, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3928], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0181, -0.3545]], requires_grad=True), Parameter containing:
# tensor([-0.0629], requires_grad=True)]
# loss: tensor(0.3686, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4915], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0109, -0.3255]], requires_grad=True), Parameter containing:
# tensor([-0.0339], requires_grad=True)]
# loss: tensor(0.2416, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4881], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0109, -0.3255]], requires_grad=True), Parameter containing:
# tensor([-0.0585], requires_grad=True)]
# loss: tensor(0.2383, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3993], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0135, -0.3255]], requires_grad=True), Parameter containing:
# tensor([-0.0828], requires_grad=True)]
# loss: tensor(0.1594, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3869], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0135, -0.3447]], requires_grad=True), Parameter containing:
# tensor([-0.1020], requires_grad=True)]
# loss: tensor(0.3758, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4818], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0156, -0.3156]], requires_grad=True), Parameter containing:
# tensor([-0.0729], requires_grad=True)]
# loss: tensor(0.2321, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4797], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0156, -0.3156]], requires_grad=True), Parameter containing:
# tensor([-0.0970], requires_grad=True)]
# loss: tensor(0.2301, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3926], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0084, -0.3156]], requires_grad=True), Parameter containing:
# tensor([-0.1209], requires_grad=True)]
# loss: tensor(0.1541, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3817], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0084, -0.3343]], requires_grad=True), Parameter containing:
# tensor([-0.1396], requires_grad=True)]
# loss: tensor(0.3823, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4724], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0208, -0.3051]], requires_grad=True), Parameter containing:
# tensor([-0.1105], requires_grad=True)]
# loss: tensor(0.2232, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4717], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0208, -0.3051]], requires_grad=True), Parameter containing:
# tensor([-0.1340], requires_grad=True)]
# loss: tensor(0.2225, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3864], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0027, -0.3051]], requires_grad=True), Parameter containing:
# tensor([-0.1575], requires_grad=True)]
# loss: tensor(0.1493, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3771], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0027, -0.3234]], requires_grad=True), Parameter containing:
# tensor([-0.1758], requires_grad=True)]
# loss: tensor(0.3880, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4634], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0266, -0.2942]], requires_grad=True), Parameter containing:
# tensor([-0.1466], requires_grad=True)]
# loss: tensor(0.2148, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4643], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0266, -0.2942]], requires_grad=True), Parameter containing:
# tensor([-0.1696], requires_grad=True)]
# loss: tensor(0.2156, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3806], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0035, -0.2942]], requires_grad=True), Parameter containing:
# tensor([-0.1927], requires_grad=True)]
# loss: tensor(0.1449, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3730], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0035, -0.3121]], requires_grad=True), Parameter containing:
# tensor([-0.2107], requires_grad=True)]
# loss: tensor(0.3931, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4548], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0328, -0.2828]], requires_grad=True), Parameter containing:
# tensor([-0.1813], requires_grad=True)]
# loss: tensor(0.2068, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4573], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0328, -0.2828]], requires_grad=True), Parameter containing:
# tensor([-0.2039], requires_grad=True)]
# loss: tensor(0.2092, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3753], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0101, -0.2828]], requires_grad=True), Parameter containing:
# tensor([-0.2266], requires_grad=True)]
# loss: tensor(0.1409, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3695], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0101, -0.3004]], requires_grad=True), Parameter containing:
# tensor([-0.2442], requires_grad=True)]
# loss: tensor(0.3976, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4465], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0395, -0.2710]], requires_grad=True), Parameter containing:
# tensor([-0.2148], requires_grad=True)]
# loss: tensor(0.1994, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4508], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0395, -0.2710]], requires_grad=True), Parameter containing:
# tensor([-0.2369], requires_grad=True)]
# loss: tensor(0.2032, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3705], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0172, -0.2710]], requires_grad=True), Parameter containing:
# tensor([-0.2592], requires_grad=True)]
# loss: tensor(0.1372, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3664], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0172, -0.2883]], requires_grad=True), Parameter containing:
# tensor([-0.2765], requires_grad=True)]
# loss: tensor(0.4014, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4385], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0466, -0.2589]], requires_grad=True), Parameter containing:
# tensor([-0.2471], requires_grad=True)]
# loss: tensor(0.1923, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4447], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0466, -0.2589]], requires_grad=True), Parameter containing:
# tensor([-0.2687], requires_grad=True)]
# loss: tensor(0.1978, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3660], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0246, -0.2589]], requires_grad=True), Parameter containing:
# tensor([-0.2906], requires_grad=True)]
# loss: tensor(0.1339, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3638], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0246, -0.2759]], requires_grad=True), Parameter containing:
# tensor([-0.3076], requires_grad=True)]
# loss: tensor(0.4047, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4309], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0541, -0.2464]], requires_grad=True), Parameter containing:
# tensor([-0.2782], requires_grad=True)]
# loss: tensor(0.1857, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4390], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0541, -0.2464]], requires_grad=True), Parameter containing:
# tensor([-0.2993], requires_grad=True)]
# loss: tensor(0.1927, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3619], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0324, -0.2464]], requires_grad=True), Parameter containing:
# tensor([-0.3209], requires_grad=True)]
# loss: tensor(0.1309, grad_fn=<MseLossBackward>)
# x: tensor([1., 1.])
# predicted_output: tensor([0.3616], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0324, -0.2631]], requires_grad=True), Parameter containing:
# tensor([-0.3376], requires_grad=True)]
# loss: tensor(0.4075, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4236], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0619, -0.2337]], requires_grad=True), Parameter containing:
# tensor([-0.3082], requires_grad=True)]
# loss: tensor(0.1794, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4337], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0619, -0.2337]], requires_grad=True), Parameter containing:
# tensor([-0.3288], requires_grad=True)]
# loss: tensor(0.1881, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3581], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0406, -0.2337]], requires_grad=True), Parameter containing:
# tensor([-0.3501], requires_grad=True)]
# loss: tensor(0.1282, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3598], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0406, -0.2501]], requires_grad=True), Parameter containing:
# tensor([-0.3666], requires_grad=True)]
# loss: tensor(0.4098, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4165], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0701, -0.2206]], requires_grad=True), Parameter containing:
# tensor([-0.3371], requires_grad=True)]
# loss: tensor(0.1735, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4287], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0701, -0.2206]], requires_grad=True), Parameter containing:
# tensor([-0.3574], requires_grad=True)]
# loss: tensor(0.1838, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3546], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0491, -0.2206]], requires_grad=True), Parameter containing:
# tensor([-0.3784], requires_grad=True)]
# loss: tensor(0.1257, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3584], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0491, -0.2368]], requires_grad=True), Parameter containing:
# tensor([-0.3946], requires_grad=True)]
# loss: tensor(0.4116, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4097], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0786, -0.2073]], requires_grad=True), Parameter containing:
# tensor([-0.3651], requires_grad=True)]
# loss: tensor(0.1679, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4240], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0786, -0.2073]], requires_grad=True), Parameter containing:
# tensor([-0.3849], requires_grad=True)]
# loss: tensor(0.1798, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3514], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0579, -0.2073]], requires_grad=True), Parameter containing:
# tensor([-0.4056], requires_grad=True)]
# loss: tensor(0.1235, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3573], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0579, -0.2234]], requires_grad=True), Parameter containing:
# tensor([-0.4216], requires_grad=True)]
# loss: tensor(0.4131, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4032], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0874, -0.1938]], requires_grad=True), Parameter containing:
# tensor([-0.3921], requires_grad=True)]
# loss: tensor(0.1626, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4197], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0874, -0.1938]], requires_grad=True), Parameter containing:
# tensor([-0.4115], requires_grad=True)]
# loss: tensor(0.1761, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3485], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0670, -0.1938]], requires_grad=True), Parameter containing:
# tensor([-0.4320], requires_grad=True)]
# loss: tensor(0.1214, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3565], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0670, -0.2097]], requires_grad=True), Parameter containing:
# tensor([-0.4478], requires_grad=True)]
# loss: tensor(0.4141, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3969], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0965, -0.1801]], requires_grad=True), Parameter containing:
# tensor([-0.4183], requires_grad=True)]
# loss: tensor(0.1576, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4156], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0965, -0.1801]], requires_grad=True), Parameter containing:
# tensor([-0.4373], requires_grad=True)]
# loss: tensor(0.1727, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3458], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0763, -0.1801]], requires_grad=True), Parameter containing:
# tensor([-0.4574], requires_grad=True)]
# loss: tensor(0.1196, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3560], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0763, -0.1958]], requires_grad=True), Parameter containing:
# tensor([-0.4731], requires_grad=True)]
# loss: tensor(0.4147, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3909], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1059, -0.1663]], requires_grad=True), Parameter containing:
# tensor([-0.4436], requires_grad=True)]
# loss: tensor(0.1528, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4118], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1059, -0.1663]], requires_grad=True), Parameter containing:
# tensor([-0.4622], requires_grad=True)]
# loss: tensor(0.1696, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3434], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0859, -0.1663]], requires_grad=True), Parameter containing:
# tensor([-0.4821], requires_grad=True)]
# loss: tensor(0.1179, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3558], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0859, -0.1817]], requires_grad=True), Parameter containing:
# tensor([-0.4976], requires_grad=True)]
# loss: tensor(0.4149, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3851], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1154, -0.1522]], requires_grad=True), Parameter containing:
# tensor([-0.4681], requires_grad=True)]
# loss: tensor(0.1483, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4083], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1154, -0.1522]], requires_grad=True), Parameter containing:
# tensor([-0.4863], requires_grad=True)]
# loss: tensor(0.1667, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3411], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0957, -0.1522]], requires_grad=True), Parameter containing:
# tensor([-0.5060], requires_grad=True)]
# loss: tensor(0.1164, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3559], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0957, -0.1675]], requires_grad=True), Parameter containing:
# tensor([-0.5214], requires_grad=True)]
# loss: tensor(0.4149, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3795], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1252, -0.1380]], requires_grad=True), Parameter containing:
# tensor([-0.4918], requires_grad=True)]
# loss: tensor(0.1440, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4050], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1252, -0.1380]], requires_grad=True), Parameter containing:
# tensor([-0.5097], requires_grad=True)]
# loss: tensor(0.1641, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3391], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1057, -0.1380]], requires_grad=True), Parameter containing:
# tensor([-0.5292], requires_grad=True)]
# loss: tensor(0.1150, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3562], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1057, -0.1532]], requires_grad=True), Parameter containing:
# tensor([-0.5444], requires_grad=True)]
# loss: tensor(0.4145, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3740], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1352, -0.1237]], requires_grad=True), Parameter containing:
# tensor([-0.5149], requires_grad=True)]
# loss: tensor(0.1399, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4020], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1352, -0.1237]], requires_grad=True), Parameter containing:
# tensor([-0.5324], requires_grad=True)]
# loss: tensor(0.1616, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3373], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1159, -0.1237]], requires_grad=True), Parameter containing:
# tensor([-0.5518], requires_grad=True)]
# loss: tensor(0.1138, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3567], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1159, -0.1388]], requires_grad=True), Parameter containing:
# tensor([-0.5668], requires_grad=True)]
# loss: tensor(0.4138, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3688], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1454, -0.1092]], requires_grad=True), Parameter containing:
# tensor([-0.5373], requires_grad=True)]
# loss: tensor(0.1360, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3991], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1454, -0.1092]], requires_grad=True), Parameter containing:
# tensor([-0.5545], requires_grad=True)]
# loss: tensor(0.1593, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3356], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1263, -0.1092]], requires_grad=True), Parameter containing:
# tensor([-0.5736], requires_grad=True)]
# loss: tensor(0.1126, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3574], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1263, -0.1242]], requires_grad=True), Parameter containing:
# tensor([-0.5886], requires_grad=True)]
# loss: tensor(0.4129, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3638], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1558, -0.0947]], requires_grad=True), Parameter containing:
# tensor([-0.5591], requires_grad=True)]
# loss: tensor(0.1323, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3965], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1558, -0.0947]], requires_grad=True), Parameter containing:
# tensor([-0.5759], requires_grad=True)]
# loss: tensor(0.1572, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3341], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1368, -0.0947]], requires_grad=True), Parameter containing:
# tensor([-0.5949], requires_grad=True)]
# loss: tensor(0.1116, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3584], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1368, -0.1096]], requires_grad=True), Parameter containing:
# tensor([-0.6098], requires_grad=True)]
# loss: tensor(0.4117, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3589], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1663, -0.0801]], requires_grad=True), Parameter containing:
# tensor([-0.5803], requires_grad=True)]
# loss: tensor(0.1288, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3940], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1663, -0.0801]], requires_grad=True), Parameter containing:
# tensor([-0.5968], requires_grad=True)]
# loss: tensor(0.1553, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3328], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1475, -0.0801]], requires_grad=True), Parameter containing:
# tensor([-0.6156], requires_grad=True)]
# loss: tensor(0.1107, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3595], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1475, -0.0948]], requires_grad=True), Parameter containing:
# tensor([-0.6304], requires_grad=True)]
# loss: tensor(0.4103, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3541], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1770, -0.0653]], requires_grad=True), Parameter containing:
# tensor([-0.6009], requires_grad=True)]
# loss: tensor(0.1254, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3917], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1770, -0.0653]], requires_grad=True), Parameter containing:
# tensor([-0.6171], requires_grad=True)]
# loss: tensor(0.1535, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3316], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1583, -0.0653]], requires_grad=True), Parameter containing:
# tensor([-0.6357], requires_grad=True)]
# loss: tensor(0.1099, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3607], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1583, -0.0800]], requires_grad=True), Parameter containing:
# tensor([-0.6504], requires_grad=True)]
# loss: tensor(0.4086, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3496], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1878, -0.0505]], requires_grad=True), Parameter containing:
# tensor([-0.6209], requires_grad=True)]
# loss: tensor(0.1222, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3896], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1878, -0.0505]], requires_grad=True), Parameter containing:
# tensor([-0.6368], requires_grad=True)]
# loss: tensor(0.1518, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3305], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1693, -0.0505]], requires_grad=True), Parameter containing:
# tensor([-0.6554], requires_grad=True)]
# loss: tensor(0.1092, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3622], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1693, -0.0652]], requires_grad=True), Parameter containing:
# tensor([-0.6700], requires_grad=True)]
# loss: tensor(0.4068, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3451], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1988, -0.0357]], requires_grad=True), Parameter containing:
# tensor([-0.6405], requires_grad=True)]
# loss: tensor(0.1191, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3876], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1988, -0.0357]], requires_grad=True), Parameter containing:
# tensor([-0.6561], requires_grad=True)]
# loss: tensor(0.1502, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3295], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1804, -0.0357]], requires_grad=True), Parameter containing:
# tensor([-0.6745], requires_grad=True)]
# loss: tensor(0.1086, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3638], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1804, -0.0503]], requires_grad=True), Parameter containing:
# tensor([-0.6891], requires_grad=True)]
# loss: tensor(0.4048, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3408], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2098, -0.0208]], requires_grad=True), Parameter containing:
# tensor([-0.6596], requires_grad=True)]
# loss: tensor(0.1162, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3858], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2098, -0.0208]], requires_grad=True), Parameter containing:
# tensor([-0.6750], requires_grad=True)]
# loss: tensor(0.1488, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3287], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1915, -0.0208]], requires_grad=True), Parameter containing:
# tensor([-0.6932], requires_grad=True)]
# loss: tensor(0.1080, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3655], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1915, -0.0353]], requires_grad=True), Parameter containing:
# tensor([-0.7077], requires_grad=True)]
# loss: tensor(0.4026, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3366], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2210, -0.0059]], requires_grad=True), Parameter containing:
# tensor([-0.6783], requires_grad=True)]
# loss: tensor(0.1133, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3841], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2210, -0.0059]], requires_grad=True), Parameter containing:
# tensor([-0.6934], requires_grad=True)]
# loss: tensor(0.1475, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3280], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2028, -0.0059]], requires_grad=True), Parameter containing:
# tensor([-0.7115], requires_grad=True)]
# loss: tensor(0.1076, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3674], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2028, -0.0204]], requires_grad=True), Parameter containing:
# tensor([-0.7260], requires_grad=True)]
# loss: tensor(0.4002, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3326], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2322, 0.0091]], requires_grad=True), Parameter containing:
# tensor([-0.6966], requires_grad=True)]
# loss: tensor(0.1106, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3825], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2322, 0.0091]], requires_grad=True), Parameter containing:
# tensor([-0.7113], requires_grad=True)]
# loss: tensor(0.1463, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3273], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2141, 0.0091]], requires_grad=True), Parameter containing:
# tensor([-0.7294], requires_grad=True)]
# loss: tensor(0.1071, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3693], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2141, -0.0054]], requires_grad=True), Parameter containing:
# tensor([-0.7438], requires_grad=True)]
# loss: tensor(0.3977, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3286], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2435, 0.0240]], requires_grad=True), Parameter containing:
# tensor([-0.7144], requires_grad=True)]
# loss: tensor(0.1080, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3810], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2435, 0.0240]], requires_grad=True), Parameter containing:
# tensor([-0.7289], requires_grad=True)]
# loss: tensor(0.1451, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3268], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2255, 0.0240]], requires_grad=True), Parameter containing:
# tensor([-0.7469], requires_grad=True)]
# loss: tensor(0.1068, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3714], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.2255, 0.0096]], requires_grad=True), Parameter containing:
# tensor([-0.7613], requires_grad=True)]
# loss: tensor(0.3951, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3248], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2549, 0.0390]], requires_grad=True), Parameter containing:
# tensor([-0.7319], requires_grad=True)]
# loss: tensor(0.1055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3796], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2549, 0.0390]], requires_grad=True), Parameter containing:
# tensor([-0.7462], requires_grad=True)]
# loss: tensor(0.1441, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3263], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2370, 0.0390]], requires_grad=True), Parameter containing:
# tensor([-0.7641], requires_grad=True)]
# loss: tensor(0.1065, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3736], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.2370, 0.0247]], requires_grad=True), Parameter containing:
# tensor([-0.7784], requires_grad=True)]
# loss: tensor(0.3924, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3210], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2663, 0.0540]], requires_grad=True), Parameter containing:
# tensor([-0.7491], requires_grad=True)]
# loss: tensor(0.1031, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3783], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2663, 0.0540]], requires_grad=True), Parameter containing:
# tensor([-0.7631], requires_grad=True)]
# loss: tensor(0.1431, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3259], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2485, 0.0540]], requires_grad=True), Parameter containing:
# tensor([-0.7809], requires_grad=True)]
# loss: tensor(0.1062, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3759], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.2485, 0.0397]], requires_grad=True), Parameter containing:
# tensor([-0.7952], requires_grad=True)]
# loss: tensor(0.3895, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3174], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2778, 0.0689]], requires_grad=True), Parameter containing:
# tensor([-0.7659], requires_grad=True)]
# loss: tensor(0.1007, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3771], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2778, 0.0689]], requires_grad=True), Parameter containing:
# tensor([-0.7797], requires_grad=True)]
# loss: tensor(0.1422, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3255], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2601, 0.0689]], requires_grad=True), Parameter containing:
# tensor([-0.7974], requires_grad=True)]
# loss: tensor(0.1060, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3783], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.2601, 0.0546]], requires_grad=True), Parameter containing:
# tensor([-0.8117], requires_grad=True)]
# loss: tensor(0.3866, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3138], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2893, 0.0839]], requires_grad=True), Parameter containing:
# tensor([-0.7824], requires_grad=True)]
# loss: tensor(0.0985, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3760], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2893, 0.0839]], requires_grad=True), Parameter containing:
# tensor([-0.7959], requires_grad=True)]
# loss: tensor(0.1414, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3253], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2717, 0.0839]], requires_grad=True), Parameter containing:
# tensor([-0.8136], requires_grad=True)]
# loss: tensor(0.1058, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3807], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.2717, 0.0696]], requires_grad=True), Parameter containing:
# tensor([-0.8279], requires_grad=True)]
# loss: tensor(0.3835, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3103], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3009, 0.0988]], requires_grad=True), Parameter containing:
# tensor([-0.7987], requires_grad=True)]
# loss: tensor(0.0963, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3750], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3009, 0.0988]], requires_grad=True), Parameter containing:
# tensor([-0.8119], requires_grad=True)]
# loss: tensor(0.1406, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3250], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2833, 0.0988]], requires_grad=True), Parameter containing:
# tensor([-0.8295], requires_grad=True)]
# loss: tensor(0.1057, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3832], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.2833, 0.0845]], requires_grad=True), Parameter containing:
# tensor([-0.8438], requires_grad=True)]
# loss: tensor(0.3804, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3069], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3125, 0.1137]], requires_grad=True), Parameter containing:
# tensor([-0.8146], requires_grad=True)]
# loss: tensor(0.0942, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3740], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3125, 0.1137]], requires_grad=True), Parameter containing:
# tensor([-0.8277], requires_grad=True)]
# loss: tensor(0.1399, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3249], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.2950, 0.1137]], requires_grad=True), Parameter containing:
# tensor([-0.8452], requires_grad=True)]
# loss: tensor(0.1055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3858], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.2950, 0.0995]], requires_grad=True), Parameter containing:
# tensor([-0.8594], requires_grad=True)]
# loss: tensor(0.3772, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3036], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3241, 0.1286]], requires_grad=True), Parameter containing:
# tensor([-0.8303], requires_grad=True)]
# loss: tensor(0.0922, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3731], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3241, 0.1286]], requires_grad=True), Parameter containing:
# tensor([-0.8432], requires_grad=True)]
# loss: tensor(0.1392, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3247], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3066, 0.1286]], requires_grad=True), Parameter containing:
# tensor([-0.8606], requires_grad=True)]
# loss: tensor(0.1055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3884], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3066, 0.1143]], requires_grad=True), Parameter containing:
# tensor([-0.8749], requires_grad=True)]
# loss: tensor(0.3740, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3003], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3357, 0.1434]], requires_grad=True), Parameter containing:
# tensor([-0.8458], requires_grad=True)]
# loss: tensor(0.0902, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3722], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3357, 0.1434]], requires_grad=True), Parameter containing:
# tensor([-0.8584], requires_grad=True)]
# loss: tensor(0.1385, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3247], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3183, 0.1434]], requires_grad=True), Parameter containing:
# tensor([-0.8758], requires_grad=True)]
# loss: tensor(0.1054, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3911], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3183, 0.1291]], requires_grad=True), Parameter containing:
# tensor([-0.8901], requires_grad=True)]
# loss: tensor(0.3707, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2971], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3473, 0.1581]], requires_grad=True), Parameter containing:
# tensor([-0.8611], requires_grad=True)]
# loss: tensor(0.0883, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3714], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3473, 0.1581]], requires_grad=True), Parameter containing:
# tensor([-0.8735], requires_grad=True)]
# loss: tensor(0.1379, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3246], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3300, 0.1581]], requires_grad=True), Parameter containing:
# tensor([-0.8908], requires_grad=True)]
# loss: tensor(0.1054, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3938], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3300, 0.1439]], requires_grad=True), Parameter containing:
# tensor([-0.9050], requires_grad=True)]
# loss: tensor(0.3674, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2940], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3589, 0.1728]], requires_grad=True), Parameter containing:
# tensor([-0.8761], requires_grad=True)]
# loss: tensor(0.0864, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3707], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3589, 0.1728]], requires_grad=True), Parameter containing:
# tensor([-0.8883], requires_grad=True)]
# loss: tensor(0.1374, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3246], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3416, 0.1728]], requires_grad=True), Parameter containing:
# tensor([-0.9056], requires_grad=True)]
# loss: tensor(0.1054, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3966], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3416, 0.1586]], requires_grad=True), Parameter containing:
# tensor([-0.9198], requires_grad=True)]
# loss: tensor(0.3641, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2909], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3705, 0.1875]], requires_grad=True), Parameter containing:
# tensor([-0.8909], requires_grad=True)]
# loss: tensor(0.0846, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3699], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3705, 0.1875]], requires_grad=True), Parameter containing:
# tensor([-0.9030], requires_grad=True)]
# loss: tensor(0.1369, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3246], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3532, 0.1875]], requires_grad=True), Parameter containing:
# tensor([-0.9202], requires_grad=True)]
# loss: tensor(0.1054, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3994], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3532, 0.1733]], requires_grad=True), Parameter containing:
# tensor([-0.9344], requires_grad=True)]
# loss: tensor(0.3607, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2879], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3821, 0.2021]], requires_grad=True), Parameter containing:
# tensor([-0.9056], requires_grad=True)]
# loss: tensor(0.0829, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3693], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3821, 0.2021]], requires_grad=True), Parameter containing:
# tensor([-0.9174], requires_grad=True)]
# loss: tensor(0.1364, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3246], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3649, 0.2021]], requires_grad=True), Parameter containing:
# tensor([-0.9346], requires_grad=True)]
# loss: tensor(0.1054, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4022], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3649, 0.1878]], requires_grad=True), Parameter containing:
# tensor([-0.9489], requires_grad=True)]
# loss: tensor(0.3573, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2849], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3936, 0.2166]], requires_grad=True), Parameter containing:
# tensor([-0.9201], requires_grad=True)]
# loss: tensor(0.0812, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3686], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3936, 0.2166]], requires_grad=True), Parameter containing:
# tensor([-0.9317], requires_grad=True)]
# loss: tensor(0.1359, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3247], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3764, 0.2166]], requires_grad=True), Parameter containing:
# tensor([-0.9489], requires_grad=True)]
# loss: tensor(0.1054, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4051], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3764, 0.2023]], requires_grad=True), Parameter containing:
# tensor([-0.9631], requires_grad=True)]
# loss: tensor(0.3539, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2820], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4051, 0.2310]], requires_grad=True), Parameter containing:
# tensor([-0.9344], requires_grad=True)]
# loss: tensor(0.0795, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3680], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4051, 0.2310]], requires_grad=True), Parameter containing:
# tensor([-0.9459], requires_grad=True)]
# loss: tensor(0.1354, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3248], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3880, 0.2310]], requires_grad=True), Parameter containing:
# tensor([-0.9630], requires_grad=True)]
# loss: tensor(0.1055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4079], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3880, 0.2168]], requires_grad=True), Parameter containing:
# tensor([-0.9772], requires_grad=True)]
# loss: tensor(0.3505, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2792], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4166, 0.2454]], requires_grad=True), Parameter containing:
# tensor([-0.9486], requires_grad=True)]
# loss: tensor(0.0779, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3674], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4166, 0.2454]], requires_grad=True), Parameter containing:
# tensor([-0.9599], requires_grad=True)]
# loss: tensor(0.1350, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3249], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.3995, 0.2454]], requires_grad=True), Parameter containing:
# tensor([-0.9769], requires_grad=True)]
# loss: tensor(0.1055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4108], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.3995, 0.2311]], requires_grad=True), Parameter containing:
# tensor([-0.9912], requires_grad=True)]
# loss: tensor(0.3471, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2763], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4280, 0.2596]], requires_grad=True), Parameter containing:
# tensor([-0.9627], requires_grad=True)]
# loss: tensor(0.0764, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3669], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4280, 0.2596]], requires_grad=True), Parameter containing:
# tensor([-0.9737], requires_grad=True)]
# loss: tensor(0.1346, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3249], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4110, 0.2596]], requires_grad=True), Parameter containing:
# tensor([-0.9908], requires_grad=True)]
# loss: tensor(0.1056, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4137], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4110, 0.2454]], requires_grad=True), Parameter containing:
# tensor([-1.0050], requires_grad=True)]
# loss: tensor(0.3437, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2736], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4394, 0.2738]], requires_grad=True), Parameter containing:
# tensor([-0.9766], requires_grad=True)]
# loss: tensor(0.0748, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3663], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4394, 0.2738]], requires_grad=True), Parameter containing:
# tensor([-0.9875], requires_grad=True)]
# loss: tensor(0.1342, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3251], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4224, 0.2738]], requires_grad=True), Parameter containing:
# tensor([-1.0045], requires_grad=True)]
# loss: tensor(0.1057, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4166], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4224, 0.2596]], requires_grad=True), Parameter containing:
# tensor([-1.0187], requires_grad=True)]
# loss: tensor(0.3404, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2708], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4508, 0.2879]], requires_grad=True), Parameter containing:
# tensor([-0.9904], requires_grad=True)]
# loss: tensor(0.0734, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3658], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4508, 0.2879]], requires_grad=True), Parameter containing:
# tensor([-1.0011], requires_grad=True)]
# loss: tensor(0.1338, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3252], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4338, 0.2879]], requires_grad=True), Parameter containing:
# tensor([-1.0180], requires_grad=True)]
# loss: tensor(0.1057, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4195], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4338, 0.2737]], requires_grad=True), Parameter containing:
# tensor([-1.0323], requires_grad=True)]
# loss: tensor(0.3370, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2681], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4621, 0.3019]], requires_grad=True), Parameter containing:
# tensor([-1.0040], requires_grad=True)]
# loss: tensor(0.0719, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3653], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4621, 0.3019]], requires_grad=True), Parameter containing:
# tensor([-1.0146], requires_grad=True)]
# loss: tensor(0.1334, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3253], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4451, 0.3019]], requires_grad=True), Parameter containing:
# tensor([-1.0315], requires_grad=True)]
# loss: tensor(0.1058, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4224], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4451, 0.2877]], requires_grad=True), Parameter containing:
# tensor([-1.0458], requires_grad=True)]
# loss: tensor(0.3336, grad_fn=<MseLossBackward>)

# %% [markdown]
# ### 2-Layer And

# %%
for t in range (1, 50):
    for x, output in zip(bits, and_y):
        print("x:", x)
        predicted_output = model2(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = criterion(predicted_output, output)
        print(list(model2.parameters()))
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0., 0.])
# predicted_output: tensor([1.9666], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8000],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.2821, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.6646, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4498], requires_grad=True)]
# loss: tensor(3.8676, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([-0.4821], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2914, -0.8000],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 2.0207, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2330, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.0565], requires_grad=True)]
# loss: tensor(0.2324, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.1409], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2690, -0.8000],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9982, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0100, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1529], requires_grad=True)]
# loss: tensor(0.0199, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.0605], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2690, -0.7998],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9985, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0438, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1247], requires_grad=True)]
# loss: tensor(0.8827, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.7744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2607, -0.8080],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9903, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.2320, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3127], requires_grad=True)]
# loss: tensor(0.5997, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([-0.0111], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2607, -0.8080],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9543, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0763, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1578], requires_grad=True)]
# loss: tensor(0.0001, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.0783], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2606, -0.8080],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9542, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0713, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1600], requires_grad=True)]
# loss: tensor(0.0061, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.0186], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2606, -0.8069],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9553, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0893, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1443], requires_grad=True)]
# loss: tensor(0.9632, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.7036], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2431, -0.8244],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9378, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.1873, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3406], requires_grad=True)]
# loss: tensor(0.4950, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0160], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2431, -0.8244],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9114, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0854, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1999], requires_grad=True)]
# loss: tensor(0.0003, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.0964], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2433, -0.8244],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9117, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0923, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1967], requires_grad=True)]
# loss: tensor(0.0093, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.0264], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2433, -0.8226],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.9135, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1132, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.1774], requires_grad=True)]
# loss: tensor(0.9479, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.6494], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2213, -0.8447],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8914, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.1466, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3722], requires_grad=True)]
# loss: tensor(0.4217, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0348], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2213, -0.8447],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8724, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0991, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2423], requires_grad=True)]
# loss: tensor(0.0012, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.1184], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.2220, -0.8447],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8731, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1137, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2353], requires_grad=True)]
# loss: tensor(0.0140, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.0383], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.2220, -0.8420],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8758, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1380, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2116], requires_grad=True)]
# loss: tensor(0.9249, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.5954], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1954, -0.8685],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8492, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.1035, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4040], requires_grad=True)]
# loss: tensor(0.3545, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0477], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1954, -0.8685],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8369, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1167, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2849], requires_grad=True)]
# loss: tensor(0.0023, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.1434], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1965, -0.8685],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8380, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1361, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2753], requires_grad=True)]
# loss: tensor(0.0206, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.0543], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1965, -0.8646],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8419, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1639, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2467], requires_grad=True)]
# loss: tensor(0.8944, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.5411], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1655, -0.8956],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8109, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.0581, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4358], requires_grad=True)]
# loss: tensor(0.2928, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0560], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1655, -0.8956],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8046, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1378, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3276], requires_grad=True)]
# loss: tensor(0.0031, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.1708], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1671, -0.8956],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8062, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1599, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3164], requires_grad=True)]
# loss: tensor(0.0292, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.0743], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1671, -0.8902],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.8116, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1910, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.2822], requires_grad=True)]
# loss: tensor(0.8569, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4861], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1317, -0.9255],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7763, -0.4541], requires_grad=True), Parameter containing:
# tensor([[ 0.0105, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4674], requires_grad=True)]
# loss: tensor(0.2362, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0609], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1317, -0.9255],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7752, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1622, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3702], requires_grad=True)]
# loss: tensor(0.0037, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2001], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.1337, -0.9255],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7772, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1854, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3580], requires_grad=True)]
# loss: tensor(0.0400, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.0984], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.1337, -0.9181],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7846, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2195, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3180], requires_grad=True)]
# loss: tensor(0.8128, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.4300], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0941, -0.9577],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7451, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0391, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4983], requires_grad=True)]
# loss: tensor(0.1849, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0637], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0941, -0.9577],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7484, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1892, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4123], requires_grad=True)]
# loss: tensor(0.0041, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2309], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0965, -0.9577],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7508, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2127, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3995], requires_grad=True)]
# loss: tensor(0.0533, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.1267], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0965, -0.9479],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7606, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2493, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3534], requires_grad=True)]
# loss: tensor(0.7627, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3727], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0530, -0.9914],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7171, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.0905, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5280], requires_grad=True)]
# loss: tensor(0.1389, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0653], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0530, -0.9914],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7238, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2185, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4535], requires_grad=True)]
# loss: tensor(0.0043, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2627], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0558, -0.9914],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7267, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2417, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4404], requires_grad=True)]
# loss: tensor(0.0690, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.1590], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0558, -0.9787],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7394, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2803, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.3879], requires_grad=True)]
# loss: tensor(0.7073, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3142], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0087, -1.0258],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6923, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1430, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5561], requires_grad=True)]
# loss: tensor(0.0987, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0670], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0087, -1.0258],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7012, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2493, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4932], requires_grad=True)]
# loss: tensor(0.0045, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2951], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[ 0.0120, -1.0258],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7046, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2722, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4799], requires_grad=True)]
# loss: tensor(0.0871, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.1951], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[ 0.0120, -1.0098],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7206, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3123, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4208], requires_grad=True)]
# loss: tensor(0.6479, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2546], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0382, -1.0600],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6704, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.1959, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5818], requires_grad=True)]
# loss: tensor(0.0648, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0695], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0382, -1.0600],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6803, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2809, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5309], requires_grad=True)]
# loss: tensor(0.0048, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3274], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0343, -1.0600],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6843, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3038, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5170], requires_grad=True)]
# loss: tensor(0.1072, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.2345], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0343, -1.0402],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7041, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3446, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4515], requires_grad=True)]
# loss: tensor(0.5860, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.1947], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0871, -1.0929],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6514, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2482, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6046], requires_grad=True)]
# loss: tensor(0.0379, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0738], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0871, -1.0929],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6610, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3125, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5657], requires_grad=True)]
# loss: tensor(0.0054, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3586], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.0825, -1.0929],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6657, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3358, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5509], requires_grad=True)]
# loss: tensor(0.1286, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.2763], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.0825, -1.0688],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6897, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3768, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.4792], requires_grad=True)]
# loss: tensor(0.5237, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.1352], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.1370, -1.1234],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6352, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.2989, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6239], requires_grad=True)]
# loss: tensor(0.0183, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0801], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.1370, -1.1234],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6433, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3431, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5969], requires_grad=True)]
# loss: tensor(0.0064, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3879], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.1315, -1.1234],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6488, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3672, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5809], requires_grad=True)]
# loss: tensor(0.1505, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3193], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.1315, -1.0949],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6773, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4080, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5033], requires_grad=True)]
# loss: tensor(0.4633, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.0773], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.1871, -1.1504],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6217, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3466, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6394], requires_grad=True)]
# loss: tensor(0.0060, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0887], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.1871, -1.1504],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6271, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3717, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6240], requires_grad=True)]
# loss: tensor(0.0079, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4143], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.1805, -1.1504],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6337, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3972, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6062], requires_grad=True)]
# loss: tensor(0.1716, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.3622], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.1805, -1.1175],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6666, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4373, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5234], requires_grad=True)]
# loss: tensor(0.4068, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.0223], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.2363, -1.1733],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6108, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3903, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6509], requires_grad=True)]
# loss: tensor(0.0005, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.0995], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.2363, -1.1733],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6125, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.3974, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6465], requires_grad=True)]
# loss: tensor(0.0099, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4366], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.2283, -1.1733],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6205, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4248, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6266], requires_grad=True)]
# loss: tensor(0.1906, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4033], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.2283, -1.1362],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6576, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4639, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5393], requires_grad=True)]
# loss: tensor(0.3560, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.0286], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.2837, -1.1916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6022, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4289, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6586], requires_grad=True)]
# loss: tensor(0.0008, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1119], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.2837, -1.1916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5997, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4197, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6643], requires_grad=True)]
# loss: tensor(0.0125, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4544], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.2743, -1.1916],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6091, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4492, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6419], requires_grad=True)]
# loss: tensor(0.2064, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4415], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.2743, -1.1507],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6500, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4871, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5511], requires_grad=True)]
# loss: tensor(0.3119, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.0744], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.3287, -1.2052],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5955, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4620, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6628], requires_grad=True)]
# loss: tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1254], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.3287, -1.2052],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5887, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4383, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6776], requires_grad=True)]
# loss: tensor(0.0157, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4672], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.3177, -1.2052],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5997, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4699, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6526], requires_grad=True)]
# loss: tensor(0.2183, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4757], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.3177, -1.1612],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6436, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5067, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5591], requires_grad=True)]
# loss: tensor(0.2749, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.1145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.3709, -1.2144],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5904, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4895, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6640], requires_grad=True)]
# loss: tensor(0.0131, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1394], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.3709, -1.2144],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5792, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4531, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6869], requires_grad=True)]
# loss: tensor(0.0194, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4753], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.3582, -1.2144],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5919, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4868, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6590], requires_grad=True)]
# loss: tensor(0.2259, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5055], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.3582, -1.1681],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6381, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5226, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5639], requires_grad=True)]
# loss: tensor(0.2445, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.1487], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4099, -1.2198],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5864, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5116, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6628], requires_grad=True)]
# loss: tensor(0.0221, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1533], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4099, -1.2198],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5712, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4644, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6926], requires_grad=True)]
# loss: tensor(0.0235, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4791], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.3957, -1.2198],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5855, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5000, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6619], requires_grad=True)]
# loss: tensor(0.2295, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5309], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.3957, -1.1719],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6334, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5350, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5661], requires_grad=True)]
# loss: tensor(0.2200, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.1773], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4459, -1.2221],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5832, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5289, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6599], requires_grad=True)]
# loss: tensor(0.0314, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1667], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4459, -1.2221],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5644, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4727, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6954], requires_grad=True)]
# loss: tensor(0.0278, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4794], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4301, -1.2221],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5802, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5100, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6621], requires_grad=True)]
# loss: tensor(0.2299, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5521], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.4301, -1.1732],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6291, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5443, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5662], requires_grad=True)]
# loss: tensor(0.2006, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2008], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4789, -1.2219],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5803, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5420, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6557], requires_grad=True)]
# loss: tensor(0.0403, grad_fn=<MseLossBackward>)
# x: tensor([1., 0.])
# predicted_output: tensor([0.1792], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4789, -1.2219],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5585, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4785, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6959], requires_grad=True)]
# loss: tensor(0.0321, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4771], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4617, -1.2219],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5757, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5172, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6601], requires_grad=True)]
# loss: tensor(0.2276, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5646], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.4617, -1.1726],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6251, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5510, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5646], requires_grad=True)]
# loss: tensor(0.1895, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2437], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4617, -1.1726],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6251, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5510, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6517], requires_grad=True)]
# loss: tensor(0.0594, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1643], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4617, -1.1726],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5982, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4718, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7005], requires_grad=True)]
# loss: tensor(0.0270, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4430], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4462, -1.1726],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6137, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5091, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6676], requires_grad=True)]
# loss: tensor(0.1963, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5323], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.4462, -1.1275],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6588, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5482, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5790], requires_grad=True)]
# loss: tensor(0.2187, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.1960], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4975, -1.1788],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6075, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5403, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6725], requires_grad=True)]
# loss: tensor(0.0384, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1921], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4975, -1.1788],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5864, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4773, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7117], requires_grad=True)]
# loss: tensor(0.0369, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4522], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.4792, -1.1788],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6047, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5191, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6733], requires_grad=True)]
# loss: tensor(0.2045, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5602], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.4792, -1.1318],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6516, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5576, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5829], requires_grad=True)]
# loss: tensor(0.1934, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2170], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5282, -1.1809],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6026, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5540, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6708], requires_grad=True)]
# loss: tensor(0.0471, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.2054], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5282, -1.1809],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5785, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4845, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7142], requires_grad=True)]
# loss: tensor(0.0422, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4528], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5083, -1.1809],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5984, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5276, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6732], requires_grad=True)]
# loss: tensor(0.2051, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5799], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.5083, -1.1331],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6462, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5654, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5826], requires_grad=True)]
# loss: tensor(0.1765, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2367], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5558, -1.1806],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5987, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5650, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6666], requires_grad=True)]
# loss: tensor(0.0560, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.2167], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5558, -1.1806],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5720, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4893, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7140], requires_grad=True)]
# loss: tensor(0.0470, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4505], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5346, -1.1806],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5932, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5334, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6706], requires_grad=True)]
# loss: tensor(0.2030, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5805], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.5346, -1.1325],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6412, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5706, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5805], requires_grad=True)]
# loss: tensor(0.1760, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2720], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5346, -1.1325],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6412, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5706, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6644], requires_grad=True)]
# loss: tensor(0.0740, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.2012], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5346, -1.1325],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6102, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.4813, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7188], requires_grad=True)]
# loss: tensor(0.0405, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4179], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5152, -1.1325],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6296, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5245, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6786], requires_grad=True)]
# loss: tensor(0.1746, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5557], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.5152, -1.0887],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6734, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5661, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.5950], requires_grad=True)]
# loss: tensor(0.1974, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2249], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5656, -1.1390],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6231, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5599, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6839], requires_grad=True)]
# loss: tensor(0.0506, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.2262], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.5656, -1.1390],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.5979, -0.4541], requires_grad=True), Parameter containing:
# ...
# tensor([0.7067], requires_grad=True)]
# loss: tensor(0.1057, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.2839], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6739, -1.0109],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6398, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5051, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7718], requires_grad=True)]
# loss: tensor(0.0806, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3468], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6453, -1.0109],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6685, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5599, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7150], requires_grad=True)]
# loss: tensor(0.1203, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5911], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.6453, -0.9721],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7074, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6055, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6456], requires_grad=True)]
# loss: tensor(0.1672, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2643], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6948, -1.0216],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6578, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5982, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7274], requires_grad=True)]
# loss: tensor(0.0698, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3047], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6948, -1.0216],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6262, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5105, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7803], requires_grad=True)]
# loss: tensor(0.0928, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3587], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6637, -1.0216],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6573, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5673, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7193], requires_grad=True)]
# loss: tensor(0.1286, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6148], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.6637, -0.9809],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6980, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6129, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6476], requires_grad=True)]
# loss: tensor(0.1484, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2804], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7109, -1.0281],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6508, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6088, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7246], requires_grad=True)]
# loss: tensor(0.0786, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3131], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7109, -1.0281],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6167, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5162, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7807], requires_grad=True)]
# loss: tensor(0.0980, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3623], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6786, -1.0281],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6490, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5729, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7181], requires_grad=True)]
# loss: tensor(0.1313, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6299], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.6786, -0.9866],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6905, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6179, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6456], requires_grad=True)]
# loss: tensor(0.1370, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2937], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7243, -1.0323],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6448, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6161, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7196], requires_grad=True)]
# loss: tensor(0.0862, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3190], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7243, -1.0323],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6086, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5195, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7784], requires_grad=True)]
# loss: tensor(0.1018, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3636], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6912, -1.0323],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6417, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5759, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7146], requires_grad=True)]
# loss: tensor(0.1322, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6406], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.6912, -0.9905],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6836, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6202, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6418], requires_grad=True)]
# loss: tensor(0.1292, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3026], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7357, -1.0350],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6390, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6200, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7137], requires_grad=True)]
# loss: tensor(0.0915, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3233], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7357, -1.0350],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6015, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5209, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7742], requires_grad=True)]
# loss: tensor(0.1045, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3634], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7021, -1.0350],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6352, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5768, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7096], requires_grad=True)]
# loss: tensor(0.1320, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6369], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7021, -0.9931],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6771, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6205, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6369], requires_grad=True)]
# loss: tensor(0.1318, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3311], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7021, -0.9931],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6771, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6205, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7095], requires_grad=True)]
# loss: tensor(0.1096, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3000], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7021, -0.9931],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6360, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5094, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7757], requires_grad=True)]
# loss: tensor(0.0900, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3349], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6715, -0.9931],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6666, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5654, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7157], requires_grad=True)]
# loss: tensor(0.1122, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6013], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.6715, -0.9552],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.7045, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6106, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6488], requires_grad=True)]
# loss: tensor(0.1590, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2722], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7202, -1.0039],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6558, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6044, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7285], requires_grad=True)]
# loss: tensor(0.0741, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3187], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7202, -1.0039],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6229, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5142, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7829], requires_grad=True)]
# loss: tensor(0.1016, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3465], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.6874, -1.0039],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6557, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5718, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7192], requires_grad=True)]
# loss: tensor(0.1201, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6230], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.6874, -0.9643],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6953, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6169, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6499], requires_grad=True)]
# loss: tensor(0.1421, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2865], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7339, -1.0108],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6488, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6136, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7253], requires_grad=True)]
# loss: tensor(0.0821, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3259], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7339, -1.0108],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6136, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5192, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7826], requires_grad=True)]
# loss: tensor(0.1062, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3504], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7001, -1.0108],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6475, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5765, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7174], requires_grad=True)]
# loss: tensor(0.1228, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6366], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7001, -0.9704],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6879, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6211, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6473], requires_grad=True)]
# loss: tensor(0.1321, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.2982], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7452, -1.0156],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6427, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6199, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7200], requires_grad=True)]
# loss: tensor(0.0889, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3306], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7452, -1.0156],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6057, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5219, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7797], requires_grad=True)]
# loss: tensor(0.1093, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3520], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -1.0156],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6402, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.5788, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7135], requires_grad=True)]
# loss: tensor(0.1239, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.6431], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.6431], requires_grad=True)]
# loss: tensor(0.1273, grad_fn=<MseLossBackward>)

# %% [markdown]
# ### Logsitic Regression Xor

# %%
for t in range (1, 50):
    for x, output in zip(bits, xor_y):
        print("x:", x)
        predicted_output = model(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = criterion(predicted_output, output)
        print(list(model.parameters()))
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0., 0.])
# predicted_output: tensor([0.2655], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4733, 0.3158]], requires_grad=True), Parameter containing:
# tensor([-1.0176], requires_grad=True)]
# loss: tensor(0.0705, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3648], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4733, 0.3158]], requires_grad=True), Parameter containing:
# tensor([-1.0279], requires_grad=True)]
# loss: tensor(0.4035, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3357], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5028, 0.3158]], requires_grad=True), Parameter containing:
# tensor([-0.9985], requires_grad=True)]
# loss: tensor(0.4413, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4699], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5028, 0.3455]], requires_grad=True), Parameter containing:
# tensor([-0.9689], requires_grad=True)]
# loss: tensor(0.2208, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2705], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4794, 0.3221]], requires_grad=True), Parameter containing:
# tensor([-0.9923], requires_grad=True)]
# loss: tensor(0.0731, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3720], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4794, 0.3221]], requires_grad=True), Parameter containing:
# tensor([-1.0030], requires_grad=True)]
# loss: tensor(0.3944, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3426], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5087, 0.3221]], requires_grad=True), Parameter containing:
# tensor([-0.9736], requires_grad=True)]
# loss: tensor(0.4321, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4791], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5087, 0.3517]], requires_grad=True), Parameter containing:
# tensor([-0.9440], requires_grad=True)]
# loss: tensor(0.2295, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2753], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4848, 0.3278]], requires_grad=True), Parameter containing:
# tensor([-0.9679], requires_grad=True)]
# loss: tensor(0.0758, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3789], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4848, 0.3278]], requires_grad=True), Parameter containing:
# tensor([-0.9789], requires_grad=True)]
# loss: tensor(0.3857, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3493], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5140, 0.3278]], requires_grad=True), Parameter containing:
# tensor([-0.9497], requires_grad=True)]
# loss: tensor(0.4234, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4878], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5140, 0.3573]], requires_grad=True), Parameter containing:
# tensor([-0.9201], requires_grad=True)]
# loss: tensor(0.2380, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2800], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4896, 0.3330]], requires_grad=True), Parameter containing:
# tensor([-0.9445], requires_grad=True)]
# loss: tensor(0.0784, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3855], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4896, 0.3330]], requires_grad=True), Parameter containing:
# tensor([-0.9558], requires_grad=True)]
# loss: tensor(0.3776, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3558], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5188, 0.3330]], requires_grad=True), Parameter containing:
# tensor([-0.9266], requires_grad=True)]
# loss: tensor(0.4150, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.4960], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5188, 0.3625]], requires_grad=True), Parameter containing:
# tensor([-0.8971], requires_grad=True)]
# loss: tensor(0.2460, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2846], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4940, 0.3377]], requires_grad=True), Parameter containing:
# tensor([-0.9219], requires_grad=True)]
# loss: tensor(0.0810, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3918], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4940, 0.3377]], requires_grad=True), Parameter containing:
# tensor([-0.9335], requires_grad=True)]
# loss: tensor(0.3698, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3620], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5229, 0.3377]], requires_grad=True), Parameter containing:
# tensor([-0.9045], requires_grad=True)]
# loss: tensor(0.4071, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5038], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5229, 0.3672]], requires_grad=True), Parameter containing:
# tensor([-0.8750], requires_grad=True)]
# loss: tensor(0.2538, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2890], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4978, 0.3420]], requires_grad=True), Parameter containing:
# tensor([-0.9002], requires_grad=True)]
# loss: tensor(0.0835, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.3979], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4978, 0.3420]], requires_grad=True), Parameter containing:
# tensor([-0.9121], requires_grad=True)]
# loss: tensor(0.3626, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3679], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5266, 0.3420]], requires_grad=True), Parameter containing:
# tensor([-0.8833], requires_grad=True)]
# loss: tensor(0.3996, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5110], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5266, 0.3714]], requires_grad=True), Parameter containing:
# tensor([-0.8539], requires_grad=True)]
# loss: tensor(0.2611, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2933], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5011, 0.3458]], requires_grad=True), Parameter containing:
# tensor([-0.8794], requires_grad=True)]
# loss: tensor(0.0860, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4036], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5011, 0.3458]], requires_grad=True), Parameter containing:
# tensor([-0.8916], requires_grad=True)]
# loss: tensor(0.3557, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3736], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5298, 0.3458]], requires_grad=True), Parameter containing:
# tensor([-0.8628], requires_grad=True)]
# loss: tensor(0.3924, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5178], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5298, 0.3752]], requires_grad=True), Parameter containing:
# tensor([-0.8335], requires_grad=True)]
# loss: tensor(0.2682, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.2975], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5039, 0.3493]], requires_grad=True), Parameter containing:
# tensor([-0.8594], requires_grad=True)]
# loss: tensor(0.0885, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4090], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5039, 0.3493]], requires_grad=True), Parameter containing:
# tensor([-0.8718], requires_grad=True)]
# loss: tensor(0.3492, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3790], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5325, 0.3493]], requires_grad=True), Parameter containing:
# tensor([-0.8433], requires_grad=True)]
# loss: tensor(0.3857, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5242], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5325, 0.3785]], requires_grad=True), Parameter containing:
# tensor([-0.8140], requires_grad=True)]
# loss: tensor(0.2748, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3015], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5063, 0.3524]], requires_grad=True), Parameter containing:
# tensor([-0.8402], requires_grad=True)]
# loss: tensor(0.0909, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4142], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5063, 0.3524]], requires_grad=True), Parameter containing:
# tensor([-0.8529], requires_grad=True)]
# loss: tensor(0.3431, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3841], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5348, 0.3524]], requires_grad=True), Parameter containing:
# tensor([-0.8244], requires_grad=True)]
# loss: tensor(0.3793, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5302], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5348, 0.3815]], requires_grad=True), Parameter containing:
# tensor([-0.7953], requires_grad=True)]
# loss: tensor(0.2811, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3054], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5084, 0.3551]], requires_grad=True), Parameter containing:
# tensor([-0.8217], requires_grad=True)]
# loss: tensor(0.0933, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4191], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5084, 0.3551]], requires_grad=True), Parameter containing:
# tensor([-0.8347], requires_grad=True)]
# loss: tensor(0.3374, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3891], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5366, 0.3551]], requires_grad=True), Parameter containing:
# tensor([-0.8064], requires_grad=True)]
# loss: tensor(0.3733, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5358], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5366, 0.3841]], requires_grad=True), Parameter containing:
# tensor([-0.7773], requires_grad=True)]
# loss: tensor(0.2871, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3092], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5100, 0.3575]], requires_grad=True), Parameter containing:
# tensor([-0.8040], requires_grad=True)]
# loss: tensor(0.0956, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4238], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5100, 0.3575]], requires_grad=True), Parameter containing:
# tensor([-0.8172], requires_grad=True)]
# loss: tensor(0.3320, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3938], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5381, 0.3575]], requires_grad=True), Parameter containing:
# tensor([-0.7891], requires_grad=True)]
# loss: tensor(0.3675, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5410], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5381, 0.3864]], requires_grad=True), Parameter containing:
# tensor([-0.7601], requires_grad=True)]
# loss: tensor(0.2927, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3128], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5113, 0.3596]], requires_grad=True), Parameter containing:
# tensor([-0.7870], requires_grad=True)]
# loss: tensor(0.0979, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4282], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5113, 0.3596]], requires_grad=True), Parameter containing:
# tensor([-0.8004], requires_grad=True)]
# loss: tensor(0.3270, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.3982], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5393, 0.3596]], requires_grad=True), Parameter containing:
# tensor([-0.7724], requires_grad=True)]
# loss: tensor(0.3621, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5459], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5393, 0.3884]], requires_grad=True), Parameter containing:
# tensor([-0.7436], requires_grad=True)]
# loss: tensor(0.2980, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3163], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5122, 0.3613]], requires_grad=True), Parameter containing:
# tensor([-0.7707], requires_grad=True)]
# loss: tensor(0.1001, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4324], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5122, 0.3613]], requires_grad=True), Parameter containing:
# tensor([-0.7843], requires_grad=True)]
# loss: tensor(0.3222, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4025], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5401, 0.3613]], requires_grad=True), Parameter containing:
# tensor([-0.7565], requires_grad=True)]
# loss: tensor(0.3570, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5504], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5401, 0.3901]], requires_grad=True), Parameter containing:
# tensor([-0.7277], requires_grad=True)]
# loss: tensor(0.3030, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3197], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5128, 0.3628]], requires_grad=True), Parameter containing:
# tensor([-0.7550], requires_grad=True)]
# loss: tensor(0.1022, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4363], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5128, 0.3628]], requires_grad=True), Parameter containing:
# tensor([-0.7689], requires_grad=True)]
# loss: tensor(0.3177, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4065], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5405, 0.3628]], requires_grad=True), Parameter containing:
# tensor([-0.7412], requires_grad=True)]
# loss: tensor(0.3522, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5547], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5405, 0.3915]], requires_grad=True), Parameter containing:
# tensor([-0.7125], requires_grad=True)]
# loss: tensor(0.3076, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3230], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5131, 0.3641]], requires_grad=True), Parameter containing:
# tensor([-0.7399], requires_grad=True)]
# loss: tensor(0.1043, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4401], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5131, 0.3641]], requires_grad=True), Parameter containing:
# tensor([-0.7541], requires_grad=True)]
# loss: tensor(0.3135, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4104], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5407, 0.3641]], requires_grad=True), Parameter containing:
# tensor([-0.7265], requires_grad=True)]
# loss: tensor(0.3476, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5586], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5407, 0.3926]], requires_grad=True), Parameter containing:
# tensor([-0.6979], requires_grad=True)]
# loss: tensor(0.3120, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3262], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5132, 0.3651]], requires_grad=True), Parameter containing:
# tensor([-0.7255], requires_grad=True)]
# loss: tensor(0.1064, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4436], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5132, 0.3651]], requires_grad=True), Parameter containing:
# tensor([-0.7398], requires_grad=True)]
# loss: tensor(0.3096, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4140], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5407, 0.3651]], requires_grad=True), Parameter containing:
# tensor([-0.7123], requires_grad=True)]
# loss: tensor(0.3433, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5622], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5407, 0.3935]], requires_grad=True), Parameter containing:
# tensor([-0.6839], requires_grad=True)]
# loss: tensor(0.3161, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3292], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5130, 0.3658]], requires_grad=True), Parameter containing:
# tensor([-0.7116], requires_grad=True)]
# loss: tensor(0.1084, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4469], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5130, 0.3658]], requires_grad=True), Parameter containing:
# tensor([-0.7261], requires_grad=True)]
# loss: tensor(0.3059, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4175], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5403, 0.3658]], requires_grad=True), Parameter containing:
# tensor([-0.6988], requires_grad=True)]
# loss: tensor(0.3393, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5656], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5403, 0.3942]], requires_grad=True), Parameter containing:
# tensor([-0.6705], requires_grad=True)]
# loss: tensor(0.3199, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3322], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5125, 0.3664]], requires_grad=True), Parameter containing:
# tensor([-0.6983], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4501], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5125, 0.3664]], requires_grad=True), Parameter containing:
# tensor([-0.7130], requires_grad=True)]
# loss: tensor(0.3024, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4208], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5397, 0.3664]], requires_grad=True), Parameter containing:
# tensor([-0.6858], requires_grad=True)]
# loss: tensor(0.3354, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5688], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5397, 0.3946]], requires_grad=True), Parameter containing:
# tensor([-0.6575], requires_grad=True)]
# loss: tensor(0.3235, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3350], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5118, 0.3667]], requires_grad=True), Parameter containing:
# tensor([-0.6854], requires_grad=True)]
# loss: tensor(0.1123, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4530], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5118, 0.3667]], requires_grad=True), Parameter containing:
# tensor([-0.7004], requires_grad=True)]
# loss: tensor(0.2992, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4240], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5390, 0.3667]], requires_grad=True), Parameter containing:
# tensor([-0.6733], requires_grad=True)]
# loss: tensor(0.3318, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5717], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5390, 0.3948]], requires_grad=True), Parameter containing:
# tensor([-0.6451], requires_grad=True)]
# loss: tensor(0.3268, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3378], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5110, 0.3668]], requires_grad=True), Parameter containing:
# tensor([-0.6731], requires_grad=True)]
# loss: tensor(0.1141, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4558], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5110, 0.3668]], requires_grad=True), Parameter containing:
# tensor([-0.6882], requires_grad=True)]
# loss: tensor(0.2962, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4269], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5380, 0.3668]], requires_grad=True), Parameter containing:
# tensor([-0.6612], requires_grad=True)]
# loss: tensor(0.3284, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5744], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5380, 0.3949]], requires_grad=True), Parameter containing:
# tensor([-0.6332], requires_grad=True)]
# loss: tensor(0.3299, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3405], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5099, 0.3668]], requires_grad=True), Parameter containing:
# tensor([-0.6613], requires_grad=True)]
# loss: tensor(0.1159, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4584], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5099, 0.3668]], requires_grad=True), Parameter containing:
# tensor([-0.6766], requires_grad=True)]
# loss: tensor(0.2933, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4297], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5368, 0.3668]], requires_grad=True), Parameter containing:
# tensor([-0.6497], requires_grad=True)]
# loss: tensor(0.3252, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5768], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5368, 0.3947]], requires_grad=True), Parameter containing:
# tensor([-0.6217], requires_grad=True)]
# loss: tensor(0.3327, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3430], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5086, 0.3666]], requires_grad=True), Parameter containing:
# tensor([-0.6499], requires_grad=True)]
# loss: tensor(0.1177, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4609], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5086, 0.3666]], requires_grad=True), Parameter containing:
# tensor([-0.6653], requires_grad=True)]
# loss: tensor(0.2906, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4324], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5354, 0.3666]], requires_grad=True), Parameter containing:
# tensor([-0.6386], requires_grad=True)]
# loss: tensor(0.3221, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5791], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5354, 0.3944]], requires_grad=True), Parameter containing:
# tensor([-0.6107], requires_grad=True)]
# loss: tensor(0.3354, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3455], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5072, 0.3662]], requires_grad=True), Parameter containing:
# tensor([-0.6389], requires_grad=True)]
# loss: tensor(0.1194, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4632], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5072, 0.3662]], requires_grad=True), Parameter containing:
# tensor([-0.6545], requires_grad=True)]
# loss: tensor(0.2881, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4350], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5339, 0.3662]], requires_grad=True), Parameter containing:
# tensor([-0.6279], requires_grad=True)]
# loss: tensor(0.3193, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5812], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5339, 0.3940]], requires_grad=True), Parameter containing:
# tensor([-0.6001], requires_grad=True)]
# loss: tensor(0.3378, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3479], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5056, 0.3657]], requires_grad=True), Parameter containing:
# tensor([-0.6284], requires_grad=True)]
# loss: tensor(0.1210, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4654], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5056, 0.3657]], requires_grad=True), Parameter containing:
# tensor([-0.6442], requires_grad=True)]
# loss: tensor(0.2858, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4374], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5322, 0.3657]], requires_grad=True), Parameter containing:
# tensor([-0.6176], requires_grad=True)]
# loss: tensor(0.3166, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5831], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5322, 0.3934]], requires_grad=True), Parameter containing:
# tensor([-0.5899], requires_grad=True)]
# loss: tensor(0.3401, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3502], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5038, 0.3650]], requires_grad=True), Parameter containing:
# tensor([-0.6182], requires_grad=True)]
# loss: tensor(0.1226, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4675], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5038, 0.3650]], requires_grad=True), Parameter containing:
# tensor([-0.6342], requires_grad=True)]
# loss: tensor(0.2836, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4396], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5303, 0.3650]], requires_grad=True), Parameter containing:
# tensor([-0.6076], requires_grad=True)]
# loss: tensor(0.3140, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5849], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5303, 0.3926]], requires_grad=True), Parameter containing:
# tensor([-0.5800], requires_grad=True)]
# loss: tensor(0.3421, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3524], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5019, 0.3642]], requires_grad=True), Parameter containing:
# tensor([-0.6084], requires_grad=True)]
# loss: tensor(0.1242, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4694], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5019, 0.3642]], requires_grad=True), Parameter containing:
# tensor([-0.6245], requires_grad=True)]
# loss: tensor(0.2815, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4418], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5284, 0.3642]], requires_grad=True), Parameter containing:
# tensor([-0.5981], requires_grad=True)]
# loss: tensor(0.3116, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5865], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5284, 0.3918]], requires_grad=True), Parameter containing:
# tensor([-0.5706], requires_grad=True)]
# loss: tensor(0.3440, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3546], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4999, 0.3633]], requires_grad=True), Parameter containing:
# tensor([-0.5990], requires_grad=True)]
# loss: tensor(0.1257, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4712], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4999, 0.3633]], requires_grad=True), Parameter containing:
# tensor([-0.6152], requires_grad=True)]
# loss: tensor(0.2796, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4438], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5263, 0.3633]], requires_grad=True), Parameter containing:
# tensor([-0.5889], requires_grad=True)]
# loss: tensor(0.3093, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5880], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5263, 0.3908]], requires_grad=True), Parameter containing:
# tensor([-0.5614], requires_grad=True)]
# loss: tensor(0.3457, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3567], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4978, 0.3623]], requires_grad=True), Parameter containing:
# tensor([-0.5899], requires_grad=True)]
# loss: tensor(0.1272, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4729], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4978, 0.3623]], requires_grad=True), Parameter containing:
# tensor([-0.6063], requires_grad=True)]
# loss: tensor(0.2778, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4458], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5241, 0.3623]], requires_grad=True), Parameter containing:
# tensor([-0.5800], requires_grad=True)]
# loss: tensor(0.3072, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5893], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5241, 0.3897]], requires_grad=True), Parameter containing:
# tensor([-0.5526], requires_grad=True)]
# loss: tensor(0.3473, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3587], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4955, 0.3611]], requires_grad=True), Parameter containing:
# tensor([-0.5811], requires_grad=True)]
# loss: tensor(0.1286, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4745], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4955, 0.3611]], requires_grad=True), Parameter containing:
# tensor([-0.5976], requires_grad=True)]
# loss: tensor(0.2762, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4476], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5217, 0.3611]], requires_grad=True), Parameter containing:
# tensor([-0.5714], requires_grad=True)]
# loss: tensor(0.3051, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5905], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5217, 0.3885]], requires_grad=True), Parameter containing:
# tensor([-0.5441], requires_grad=True)]
# loss: tensor(0.3487, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3606], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4932, 0.3599]], requires_grad=True), Parameter containing:
# tensor([-0.5727], requires_grad=True)]
# loss: tensor(0.1300, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4760], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4932, 0.3599]], requires_grad=True), Parameter containing:
# tensor([-0.5893], requires_grad=True)]
# loss: tensor(0.2746, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4494], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5193, 0.3599]], requires_grad=True), Parameter containing:
# tensor([-0.5632], requires_grad=True)]
# loss: tensor(0.3032, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5916], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5193, 0.3872]], requires_grad=True), Parameter containing:
# tensor([-0.5359], requires_grad=True)]
# loss: tensor(0.3500, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3625], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4907, 0.3586]], requires_grad=True), Parameter containing:
# tensor([-0.5645], requires_grad=True)]
# loss: tensor(0.1314, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4774], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4907, 0.3586]], requires_grad=True), Parameter containing:
# tensor([-0.5813], requires_grad=True)]
# loss: tensor(0.2731, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4510], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5168, 0.3586]], requires_grad=True), Parameter containing:
# tensor([-0.5552], requires_grad=True)]
# loss: tensor(0.3014, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5926], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5168, 0.3858]], requires_grad=True), Parameter containing:
# tensor([-0.5280], requires_grad=True)]
# loss: tensor(0.3511, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3643], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4882, 0.3571]], requires_grad=True), Parameter containing:
# tensor([-0.5566], requires_grad=True)]
# loss: tensor(0.1327, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4787], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4882, 0.3571]], requires_grad=True), Parameter containing:
# tensor([-0.5735], requires_grad=True)]
# loss: tensor(0.2718, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4526], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5142, 0.3571]], requires_grad=True), Parameter containing:
# tensor([-0.5475], requires_grad=True)]
# loss: tensor(0.2997, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5934], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5142, 0.3843]], requires_grad=True), Parameter containing:
# tensor([-0.5203], requires_grad=True)]
# loss: tensor(0.3522, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3661], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4856, 0.3556]], requires_grad=True), Parameter containing:
# tensor([-0.5490], requires_grad=True)]
# loss: tensor(0.1340, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4799], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4856, 0.3556]], requires_grad=True), Parameter containing:
# tensor([-0.5660], requires_grad=True)]
# loss: tensor(0.2705, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4540], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5115, 0.3556]], requires_grad=True), Parameter containing:
# tensor([-0.5400], requires_grad=True)]
# loss: tensor(0.2981, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5942], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5115, 0.3827]], requires_grad=True), Parameter containing:
# tensor([-0.5129], requires_grad=True)]
# loss: tensor(0.3531, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3678], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4829, 0.3540]], requires_grad=True), Parameter containing:
# tensor([-0.5416], requires_grad=True)]
# loss: tensor(0.1353, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4811], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4829, 0.3540]], requires_grad=True), Parameter containing:
# tensor([-0.5587], requires_grad=True)]
# loss: tensor(0.2693, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4554], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5088, 0.3540]], requires_grad=True), Parameter containing:
# tensor([-0.5328], requires_grad=True)]
# loss: tensor(0.2966, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5949], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5088, 0.3811]], requires_grad=True), Parameter containing:
# tensor([-0.5058], requires_grad=True)]
# loss: tensor(0.3539, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3695], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4801, 0.3524]], requires_grad=True), Parameter containing:
# tensor([-0.5344], requires_grad=True)]
# loss: tensor(0.1365, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4821], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4801, 0.3524]], requires_grad=True), Parameter containing:
# tensor([-0.5517], requires_grad=True)]
# loss: tensor(0.2682, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4568], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5060, 0.3524]], requires_grad=True), Parameter containing:
# tensor([-0.5258], requires_grad=True)]
# loss: tensor(0.2951, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5954], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5060, 0.3793]], requires_grad=True), Parameter containing:
# tensor([-0.4988], requires_grad=True)]
# loss: tensor(0.3545, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3711], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4773, 0.3507]], requires_grad=True), Parameter containing:
# tensor([-0.5275], requires_grad=True)]
# loss: tensor(0.1377, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4831], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4773, 0.3507]], requires_grad=True), Parameter containing:
# tensor([-0.5449], requires_grad=True)]
# loss: tensor(0.2672, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4580], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5031, 0.3507]], requires_grad=True), Parameter containing:
# tensor([-0.5190], requires_grad=True)]
# loss: tensor(0.2938, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5959], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5031, 0.3776]], requires_grad=True), Parameter containing:
# tensor([-0.4921], requires_grad=True)]
# loss: tensor(0.3551, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3727], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4744, 0.3489]], requires_grad=True), Parameter containing:
# tensor([-0.5208], requires_grad=True)]
# loss: tensor(0.1389, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4840], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4744, 0.3489]], requires_grad=True), Parameter containing:
# tensor([-0.5383], requires_grad=True)]
# loss: tensor(0.2662, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4592], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.5002, 0.3489]], requires_grad=True), Parameter containing:
# tensor([-0.5125], requires_grad=True)]
# loss: tensor(0.2925, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5964], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.5002, 0.3757]], requires_grad=True), Parameter containing:
# tensor([-0.4856], requires_grad=True)]
# loss: tensor(0.3556, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3742], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4715, 0.3470]], requires_grad=True), Parameter containing:
# tensor([-0.5143], requires_grad=True)]
# loss: tensor(0.1400, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4849], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4715, 0.3470]], requires_grad=True), Parameter containing:
# tensor([-0.5319], requires_grad=True)]
# loss: tensor(0.2653, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4603], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4972, 0.3470]], requires_grad=True), Parameter containing:
# tensor([-0.5061], requires_grad=True)]
# loss: tensor(0.2913, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5967], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4972, 0.3738]], requires_grad=True), Parameter containing:
# tensor([-0.4793], requires_grad=True)]
# loss: tensor(0.3560, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3757], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4685, 0.3451]], requires_grad=True), Parameter containing:
# tensor([-0.5080], requires_grad=True)]
# loss: tensor(0.1411, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4857], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4685, 0.3451]], requires_grad=True), Parameter containing:
# tensor([-0.5256], requires_grad=True)]
# loss: tensor(0.2645, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4614], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4942, 0.3451]], requires_grad=True), Parameter containing:
# tensor([-0.5000], requires_grad=True)]
# loss: tensor(0.2901, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5970], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4942, 0.3719]], requires_grad=True), Parameter containing:
# tensor([-0.4732], requires_grad=True)]
# loss: tensor(0.3564, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3771], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4655, 0.3432]], requires_grad=True), Parameter containing:
# tensor([-0.5019], requires_grad=True)]
# loss: tensor(0.1422, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4865], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4655, 0.3432]], requires_grad=True), Parameter containing:
# tensor([-0.5196], requires_grad=True)]
# loss: tensor(0.2637, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4624], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4911, 0.3432]], requires_grad=True), Parameter containing:
# tensor([-0.4940], requires_grad=True)]
# loss: tensor(0.2890, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5972], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4911, 0.3699]], requires_grad=True), Parameter containing:
# tensor([-0.4672], requires_grad=True)]
# loss: tensor(0.3566, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3785], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4624, 0.3412]], requires_grad=True), Parameter containing:
# tensor([-0.4960], requires_grad=True)]
# loss: tensor(0.1433, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4872], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4624, 0.3412]], requires_grad=True), Parameter containing:
# tensor([-0.5138], requires_grad=True)]
# loss: tensor(0.2630, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4633], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4880, 0.3412]], requires_grad=True), Parameter containing:
# tensor([-0.4882], requires_grad=True)]
# loss: tensor(0.2880, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5973], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4880, 0.3678]], requires_grad=True), Parameter containing:
# tensor([-0.4615], requires_grad=True)]
# loss: tensor(0.3568, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3798], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4593, 0.3391]], requires_grad=True), Parameter containing:
# tensor([-0.4902], requires_grad=True)]
# loss: tensor(0.1443, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4878], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4593, 0.3391]], requires_grad=True), Parameter containing:
# tensor([-0.5081], requires_grad=True)]
# loss: tensor(0.2624, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4642], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4849, 0.3391]], requires_grad=True), Parameter containing:
# tensor([-0.4825], requires_grad=True)]
# loss: tensor(0.2871, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5974], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4849, 0.3658]], requires_grad=True), Parameter containing:
# tensor([-0.4558], requires_grad=True)]
# loss: tensor(0.3569, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3812], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4561, 0.3370]], requires_grad=True), Parameter containing:
# tensor([-0.4846], requires_grad=True)]
# loss: tensor(0.1453, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4884], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4561, 0.3370]], requires_grad=True), Parameter containing:
# tensor([-0.5026], requires_grad=True)]
# loss: tensor(0.2617, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4651], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4817, 0.3370]], requires_grad=True), Parameter containing:
# tensor([-0.4770], requires_grad=True)]
# loss: tensor(0.2862, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5975], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4817, 0.3636]], requires_grad=True), Parameter containing:
# tensor([-0.4504], requires_grad=True)]
# loss: tensor(0.3570, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3825], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4530, 0.3349]], requires_grad=True), Parameter containing:
# tensor([-0.4791], requires_grad=True)]
# loss: tensor(0.1463, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4889], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4530, 0.3349]], requires_grad=True), Parameter containing:
# tensor([-0.4972], requires_grad=True)]
# loss: tensor(0.2612, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4659], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4785, 0.3349]], requires_grad=True), Parameter containing:
# tensor([-0.4716], requires_grad=True)]
# loss: tensor(0.2853, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5975], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4785, 0.3615]], requires_grad=True), Parameter containing:
# tensor([-0.4451], requires_grad=True)]
# loss: tensor(0.3570, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3837], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4498, 0.3327]], requires_grad=True), Parameter containing:
# tensor([-0.4738], requires_grad=True)]
# loss: tensor(0.1472, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4895], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4498, 0.3327]], requires_grad=True), Parameter containing:
# tensor([-0.4920], requires_grad=True)]
# loss: tensor(0.2607, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4666], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4753, 0.3327]], requires_grad=True), Parameter containing:
# tensor([-0.4664], requires_grad=True)]
# loss: tensor(0.2845, grad_fn=<MseLossBackward>)
# x: tensor([1., 1.])
# predicted_output: tensor([0.5974], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4753, 0.3593]], requires_grad=True), Parameter containing:
# tensor([-0.4399], requires_grad=True)]
# loss: tensor(0.3569, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3849], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4465, 0.3306]], requires_grad=True), Parameter containing:
# tensor([-0.4686], requires_grad=True)]
# loss: tensor(0.1482, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4899], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4465, 0.3306]], requires_grad=True), Parameter containing:
# tensor([-0.4868], requires_grad=True)]
# loss: tensor(0.2602, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4673], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4720, 0.3306]], requires_grad=True), Parameter containing:
# tensor([-0.4614], requires_grad=True)]
# loss: tensor(0.2837, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5973], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4720, 0.3571]], requires_grad=True), Parameter containing:
# tensor([-0.4348], requires_grad=True)]
# loss: tensor(0.3568, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3861], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4433, 0.3283]], requires_grad=True), Parameter containing:
# tensor([-0.4636], requires_grad=True)]
# loss: tensor(0.1491, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4904], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4433, 0.3283]], requires_grad=True), Parameter containing:
# tensor([-0.4819], requires_grad=True)]
# loss: tensor(0.2597, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4680], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4688, 0.3283]], requires_grad=True), Parameter containing:
# tensor([-0.4564], requires_grad=True)]
# loss: tensor(0.2830, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5972], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4688, 0.3548]], requires_grad=True), Parameter containing:
# tensor([-0.4299], requires_grad=True)]
# loss: tensor(0.3566, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3873], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4400, 0.3261]], requires_grad=True), Parameter containing:
# tensor([-0.4586], requires_grad=True)]
# loss: tensor(0.1500, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4908], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4400, 0.3261]], requires_grad=True), Parameter containing:
# tensor([-0.4770], requires_grad=True)]
# loss: tensor(0.2593, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4687], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4655, 0.3261]], requires_grad=True), Parameter containing:
# tensor([-0.4516], requires_grad=True)]
# loss: tensor(0.2823, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5970], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4655, 0.3526]], requires_grad=True), Parameter containing:
# tensor([-0.4251], requires_grad=True)]
# loss: tensor(0.3564, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([0.3884], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4368, 0.3238]], requires_grad=True), Parameter containing:
# tensor([-0.4538], requires_grad=True)]
# loss: tensor(0.1509, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.4911], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4368, 0.3238]], requires_grad=True), Parameter containing:
# tensor([-0.4723], requires_grad=True)]
# loss: tensor(0.2590, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.4693], grad_fn=<SigmoidBackward>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[0.4622, 0.3238]], requires_grad=True), Parameter containing:
# tensor([-0.4469], requires_grad=True)]
# loss: tensor(0.2817, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.5968], grad_fn=<SigmoidBackward>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[0.4622, 0.3503]], requires_grad=True), Parameter containing:
# tensor([-0.4204], requires_grad=True)]
# loss: tensor(0.3561, grad_fn=<MseLossBackward>)

# %% [markdown]
# ### 2-Layer Xor

# %%
for t in range (1, 50):
    for x, output in zip(bits, xor_y):
        print("x:", x)
        predicted_output = model2(x)
        print("predicted_output:", predicted_output)
        print("output:", output)
        loss = criterion(predicted_output, output)
        print(list(model2.parameters()))
        print("loss:", loss, "\n\n")
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# ...
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 0.])
# predicted_output: tensor([-0.3323], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.1104, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 0.])
# predicted_output: tensor([0.1103], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.7916, grad_fn=<MseLossBackward>)
#
#
# x: tensor([0., 1.])
# predicted_output: tensor([0.2748], grad_fn=<AddBackward0>)
# output: tensor([1.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5260, grad_fn=<MseLossBackward>)
#
#
# x: tensor([1., 1.])
# predicted_output: tensor([0.7145], grad_fn=<AddBackward0>)
# output: tensor([0.])
# [Parameter containing:
# tensor([[-0.7107, -0.9748],
#         [-0.5314, -0.2553]], requires_grad=True), Parameter containing:
# tensor([ 1.6810, -0.4541], requires_grad=True), Parameter containing:
# tensor([[-0.6227, -0.2972]], requires_grad=True), Parameter containing:
# tensor([0.7145], requires_grad=True)]
# loss: tensor(0.5105, grad_fn=<MseLossBackward>)

# %% [markdown]
# # Word Embeddings
#
#
# ![WordEmbeddings](Pictures/IntroHLT/WordEmbeddings.png)
#
# These are manually chosen features. How does one choose them? Instead, today, most methods learn them automatically.

# %% [markdown]
# ## One-hot Vector
#
# ![OneHot](Pictures/IntroHLT/OneHot.png)
